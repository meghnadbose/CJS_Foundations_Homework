# %% [markdown]
# ## Meghnad Bose
# ## Homework 05

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## What is the URL to the documentation?

# %% [markdown]
# [https://www.weatherapi.com/docs/](https://www.weatherapi.com/docs/)

# %%
API_KEY = os.getenv("API_KEY")

# %% [markdown]
# ## Make a request for the current weather where you are born, or somewhere you've lived.

# %%
import requests

url = f'http://api.weatherapi.com/v1/current.json?key={API_KEY}&q=Kolkata'
response = requests.get(url)
data = response.json()

# %%
data
# Out:
# {'location': {'name': 'Kolkata',
#   'region': 'West Bengal',
#   'country': 'India',
#   'lat': 22.57,
#   'lon': 88.37,
#   'tz_id': 'Asia/Kolkata',
#   'localtime_epoch': 1700022413,
#   'localtime': '2023-11-15 9:56'},
#  'current': {'last_updated_epoch': 1700021700,
#   'last_updated': '2023-11-15 09:45',
#   'temp_c': 27.0,
#   'temp_f': 80.6,
#   'is_day': 1,
#   'condition': {'text': 'Mist',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/143.png',
#    'code': 1030},
#   'wind_mph': 4.3,
#   'wind_kph': 6.8,
#   'wind_degree': 20,
#   'wind_dir': 'NNE',
#   'pressure_mb': 1017.0,
#   'pressure_in': 30.03,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 70,
#   'cloud': 50,
#   'feelslike_c': 27.6,
#   'feelslike_f': 81.7,
#   'vis_km': 3.2,
#   'vis_miles': 1.0,
#   'uv': 7.0,
#   'gust_mph': 9.0,
#   'gust_kph': 14.5}}

# %% [markdown]
# ## Print out the country this location is in.

# %%
data.keys()
# Out:
# dict_keys(['location', 'current'])

# %%
data['location'].keys()
# Out:
# dict_keys(['name', 'region', 'country', 'lat', 'lon', 'tz_id', 'localtime_epoch', 'localtime'])

# %%
country = data['location']['country']
print(f'The country this location is in: {country}')
# Out:
# The country this location is in: India

# %% [markdown]
# ## Print out the difference between the current temperature and how warm it feels. Use "It feels ___ degrees colder" or "It feels ___ degrees warmer," not negative numbers.

# %%
current_temp = data['current']['temp_c']
feels_like = data['current']['feelslike_c']

if (current_temp > feels_like):
    print(f'It feels {(current_temp - feels_like):.2f} degrees Celsius colder')
elif (feels_like > current_temp):
    print(f'It feels {(feels_like - current_temp):.2f} degrees Celsius warmer')
elif (current_temp == feels_like):
    print(f'It feels like the actual temperature.')
# Out:
# It feels 0.60 degrees Celsius warmer

# %% [markdown]
# ## What's the current temperature at Heathrow International Airport? Use the airport's IATA code to search.

# %%
url = f'http://api.weatherapi.com/v1/current.json?key={API_KEY}&q=iata:LHR'
response = requests.get(url)
data = response.json()

# %%
data
# Out:
# {'location': {'name': 'London',
#   'region': '',
#   'country': 'United Kingdom',
#   'lat': 51.47,
#   'lon': -0.46,
#   'tz_id': 'Europe/London',
#   'localtime_epoch': 1700022373,
#   'localtime': '2023-11-15 4:26'},
#  'current': {'last_updated_epoch': 1700021700,
#   'last_updated': '2023-11-15 04:15',
#   'temp_c': 9.0,
#   'temp_f': 48.2,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 11.9,
#   'wind_kph': 19.1,
#   'wind_degree': 250,
#   'wind_dir': 'WSW',
#   'pressure_mb': 1013.0,
#   'pressure_in': 29.91,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 93,
#   'cloud': 0,
#   'feelslike_c': 6.4,
#   'feelslike_f': 43.4,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 1.0,
#   'gust_mph': 16.9,
#   'gust_kph': 27.2}}

# %%
current_temp = data['current']['temp_c']
print(f'The current temperature at Heathrow International Airport is {current_temp} degrees Celsius.')
# Out:
# The current temperature at Heathrow International Airport is 9.0 degrees Celsius.

# %% [markdown]
# ## What URL would I use to request a 3-day forecast at Heathrow?

# %% [markdown]
# The URL would be [http://api.weatherapi.com/v1/forecast.json?key={API_KEY}&q=iata:LHR&days=3](http://api.weatherapi.com/v1/forecast.json?key=38c2094a812a40b7be920812231511&q=iata:LHR&days=3)

# %% [markdown]
# ## Print the date of each of the 3 days you're getting a forecast for.

# %%
url = f'http://api.weatherapi.com/v1/forecast.json?key={API_KEY}&q=iata:LHR&days=3'
response = requests.get(url)
data = response.json()

# %%
data
# Out:
# {'location': {'name': 'London',
#   'region': '',
#   'country': 'United Kingdom',
#   'lat': 51.47,
#   'lon': -0.46,
#   'tz_id': 'Europe/London',
#   'localtime_epoch': 1700022417,
#   'localtime': '2023-11-15 4:26'},
#  'current': {'last_updated_epoch': 1700021700,
#   'last_updated': '2023-11-15 04:15',
#   'temp_c': 9.0,
#   'temp_f': 48.2,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 11.9,
#   'wind_kph': 19.1,
#   'wind_degree': 250,
#   'wind_dir': 'WSW',
#   'pressure_mb': 1013.0,
#   'pressure_in': 29.91,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 93,
#   'cloud': 0,
#   'feelslike_c': 6.4,
#   'feelslike_f': 43.4,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 1.0,
#   'gust_mph': 16.9,
#   'gust_kph': 27.2},
#  'forecast': {'forecastday': [{'date': '2023-11-15',
#     'date_epoch': 1700006400,
#     'day': {'maxtemp_c': 10.8,
#      'maxtemp_f': 51.5,
#      'mintemp_c': 7.1,
#      'mintemp_f': 44.9,
#      'avgtemp_c': 9.3,
#      'avgtemp_f': 48.7,
#      'maxwind_mph': 14.5,
#      'maxwind_kph': 23.4,
#      'totalprecip_mm': 0.21,
#      'totalprecip_in': 0.01,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 77.0,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 87,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Patchy rain possible',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'uv': 2.0},
#     'astro': {'sunrise': '07:19 AM',
#      'sunset': '04:12 PM',
#      'moonrise': '10:10 AM',
#      'moonset': '05:01 PM',
#      'moon_phase': 'Waxing Crescent',
#      'moon_illumination': 3,
#      'is_moon_up': 0,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1700006400,
#       'time': '2023-11-15 00:00',
#       'temp_c': 10.6,
#       'temp_f': 51.1,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 12.3,
#       'wind_kph': 19.8,
#       'wind_degree': 259,
#       'wind_dir': 'W',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.89,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 82,
#       'feelslike_c': 8.2,
#       'feelslike_f': 46.7,
#       'windchill_c': 8.2,
#       'windchill_f': 46.7,
#       'heatindex_c': 10.6,
#       'heatindex_f': 51.1,
#       'dewpoint_c': 7.2,
#       'dewpoint_f': 45.0,
#       'will_it_rain': 1,
#       'chance_of_rain': 72,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.7,
#       'gust_kph': 30.1,
#       'uv': 1.0},
#      {'time_epoch': 1700010000,
#       'time': '2023-11-15 01:00',
#       'temp_c': 9.7,
#       'temp_f': 49.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 11.4,
#       'wind_kph': 18.4,
#       'wind_degree': 258,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.9,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 12,
#       'feelslike_c': 7.2,
#       'feelslike_f': 45.0,
#       'windchill_c': 7.2,
#       'windchill_f': 45.0,
#       'heatindex_c': 9.8,
#       'heatindex_f': 49.6,
#       'dewpoint_c': 6.8,
#       'dewpoint_f': 44.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.1,
#       'gust_kph': 29.2,
#       'uv': 1.0},
#      {'time_epoch': 1700013600,
#       'time': '2023-11-15 02:00',
#       'temp_c': 9.2,
#       'temp_f': 48.5,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 11.6,
#       'wind_kph': 18.7,
#       'wind_degree': 256,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 89,
#       'cloud': 71,
#       'feelslike_c': 6.5,
#       'feelslike_f': 43.6,
#       'windchill_c': 6.5,
#       'windchill_f': 43.6,
#       'heatindex_c': 9.2,
#       'heatindex_f': 48.5,
#       'dewpoint_c': 7.5,
#       'dewpoint_f': 45.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.0,
#       'gust_kph': 28.9,
#       'uv': 1.0},
#      {'time_epoch': 1700017200,
#       'time': '2023-11-15 03:00',
#       'temp_c': 9.0,
#       'temp_f': 48.3,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 11.6,
#       'wind_kph': 18.7,
#       'wind_degree': 261,
#       'wind_dir': 'W',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 89,
#       'cloud': 62,
#       'feelslike_c': 6.3,
#       'feelslike_f': 43.3,
#       'windchill_c': 6.3,
#       'windchill_f': 43.3,
#       'heatindex_c': 9.0,
#       'heatindex_f': 48.3,
#       'dewpoint_c': 7.3,
#       'dewpoint_f': 45.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.9,
#       'gust_kph': 28.8,
#       'uv': 1.0},
#      {'time_epoch': 1700020800,
#       'time': '2023-11-15 04:00',
#       'temp_c': 9.0,
#       'temp_f': 48.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 11.9,
#       'wind_kph': 19.1,
#       'wind_degree': 250,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 93,
#       'cloud': 0,
#       'feelslike_c': 6.1,
#       'feelslike_f': 43.0,
#       'windchill_c': 6.1,
#       'windchill_f': 43.0,
#       'heatindex_c': 8.8,
#       'heatindex_f': 47.9,
#       'dewpoint_c': 6.9,
#       'dewpoint_f': 44.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.9,
#       'gust_kph': 27.2,
#       'uv': 1.0},
#      {'time_epoch': 1700024400,
#       'time': '2023-11-15 05:00',
#       'temp_c': 8.6,
#       'temp_f': 47.5,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 11.2,
#       'wind_kph': 18.0,
#       'wind_degree': 261,
#       'wind_dir': 'W',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'humidity': 88,
#       'cloud': 85,
#       'feelslike_c': 5.8,
#       'feelslike_f': 42.5,
#       'windchill_c': 5.8,
#       'windchill_f': 42.5,
#       'heatindex_c': 8.6,
#       'heatindex_f': 47.5,
#       'dewpoint_c': 6.7,
#       'dewpoint_f': 44.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 84,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.2,
#       'gust_kph': 27.7,
#       'uv': 1.0},
#      {'time_epoch': 1700028000,
#       'time': '2023-11-15 06:00',
#       'temp_c': 8.8,
#       'temp_f': 47.9,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 11.4,
#       'wind_kph': 18.4,
#       'wind_degree': 264,
#       'wind_dir': 'W',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 84,
#       'cloud': 70,
#       'feelslike_c': 6.1,
#       'feelslike_f': 42.9,
#       'windchill_c': 6.1,
#       'windchill_f': 42.9,
#       'heatindex_c': 8.8,
#       'heatindex_f': 47.9,
#       'dewpoint_c': 6.3,
#       'dewpoint_f': 43.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.4,
#       'gust_kph': 27.9,
#       'uv': 1.0},
#      {'time_epoch': 1700031600,
#       'time': '2023-11-15 07:00',
#       'temp_c': 8.6,
#       'temp_f': 47.5,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 11.2,
#       'wind_kph': 18.0,
#       'wind_degree': 261,
#       'wind_dir': 'W',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 35,
#       'feelslike_c': 5.8,
#       'feelslike_f': 42.5,
#       'windchill_c': 5.8,
#       'windchill_f': 42.5,
#       'heatindex_c': 8.6,
#       'heatindex_f': 47.5,
#       'dewpoint_c': 5.8,
#       'dewpoint_f': 42.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.5,
#       'gust_kph': 28.1,
#       'uv': 1.0},
#      {'time_epoch': 1700035200,
#       'time': '2023-11-15 08:00',
#       'temp_c': 8.5,
#       'temp_f': 47.3,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 11.4,
#       'wind_kph': 18.4,
#       'wind_degree': 258,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 81,
#       'cloud': 24,
#       'feelslike_c': 5.7,
#       'feelslike_f': 42.2,
#       'windchill_c': 5.7,
#       'windchill_f': 42.2,
#       'heatindex_c': 8.5,
#       'heatindex_f': 47.3,
#       'dewpoint_c': 5.5,
#       'dewpoint_f': 41.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.8,
#       'gust_kph': 28.6,
#       'uv': 3.0},
#      {'time_epoch': 1700038800,
#       'time': '2023-11-15 09:00',
#       'temp_c': 9.1,
#       'temp_f': 48.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 11.6,
#       'wind_kph': 18.7,
#       'wind_degree': 258,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 20,
#       'feelslike_c': 6.4,
#       'feelslike_f': 43.6,
#       'windchill_c': 6.4,
#       'windchill_f': 43.6,
#       'heatindex_c': 9.1,
#       'heatindex_f': 48.5,
#       'dewpoint_c': 5.9,
#       'dewpoint_f': 42.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.5,
#       'gust_kph': 26.6,
#       'uv': 3.0},
#      {'time_epoch': 1700042400,
#       'time': '2023-11-15 10:00',
#       'temp_c': 9.9,
#       'temp_f': 49.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 13.0,
#       'wind_kph': 20.9,
#       'wind_degree': 256,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 34,
#       'feelslike_c': 7.2,
#       'feelslike_f': 44.9,
#       'windchill_c': 7.2,
#       'windchill_f': 44.9,
#       'heatindex_c': 9.9,
#       'heatindex_f': 49.8,
#       'dewpoint_c': 6.0,
#       'dewpoint_f': 42.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.0,
#       'gust_kph': 27.4,
#       'uv': 3.0},
#      {'time_epoch': 1700046000,
#       'time': '2023-11-15 11:00',
#       'temp_c': 10.6,
#       'temp_f': 51.1,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 12.5,
#       'wind_kph': 20.2,
#       'wind_degree': 261,
#       'wind_dir': 'W',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 72,
#       'cloud': 27,
#       'feelslike_c': 8.2,
#       'feelslike_f': 46.7,
#       'windchill_c': 8.2,
#       'windchill_f': 46.7,
#       'heatindex_c': 10.6,
#       'heatindex_f': 51.1,
#       'dewpoint_c': 5.9,
#       'dewpoint_f': 42.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.7,
#       'gust_kph': 25.2,
#       'uv': 4.0},
#      {'time_epoch': 1700049600,
#       'time': '2023-11-15 12:00',
#       'temp_c': 11.1,
#       'temp_f': 52.0,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 13.6,
#       'wind_kph': 22.0,
#       'wind_degree': 269,
#       'wind_dir': 'W',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'humidity': 69,
#       'cloud': 83,
#       'feelslike_c': 8.6,
#       'feelslike_f': 47.5,
#       'windchill_c': 8.6,
#       'windchill_f': 47.5,
#       'heatindex_c': 11.1,
#       'heatindex_f': 52.0,
#       'dewpoint_c': 5.7,
#       'dewpoint_f': 42.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 85,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.7,
#       'gust_kph': 26.9,
#       'uv': 3.0},
#      {'time_epoch': 1700053200,
#       'time': '2023-11-15 13:00',
#       'temp_c': 11.2,
#       'temp_f': 52.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 12.1,
#       'wind_kph': 19.4,
#       'wind_degree': 269,
#       'wind_dir': 'W',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 68,
#       'cloud': 18,
#       'feelslike_c': 8.9,
#       'feelslike_f': 48.1,
#       'windchill_c': 8.9,
#       'windchill_f': 48.1,
#       'heatindex_c': 11.2,
#       'heatindex_f': 52.2,
#       'dewpoint_c': 5.4,
#       'dewpoint_f': 41.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.9,
#       'gust_kph': 23.9,
#       'uv': 4.0},
#      {'time_epoch': 1700056800,
#       'time': '2023-11-15 14:00',
#       'temp_c': 11.0,
#       'temp_f': 51.9,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 11.9,
#       'wind_kph': 19.1,
#       'wind_degree': 265,
#       'wind_dir': 'W',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 67,
#       'cloud': 29,
#       'feelslike_c': 8.8,
#       'feelslike_f': 47.8,
#       'windchill_c': 8.8,
#       'windchill_f': 47.8,
#       'heatindex_c': 11.0,
#       'heatindex_f': 51.9,
#       'dewpoint_c': 5.2,
#       'dewpoint_f': 41.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.2,
#       'gust_kph': 24.5,
#       'uv': 4.0},
#      {'time_epoch': 1700060400,
#       'time': '2023-11-15 15:00',
#       'temp_c': 10.4,
#       'temp_f': 50.7,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 11.4,
#       'wind_kph': 18.4,
#       'wind_degree': 267,
#       'wind_dir': 'W',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 70,
#       'cloud': 40,
#       'feelslike_c': 8.0,
#       'feelslike_f': 46.5,
#       'windchill_c': 8.0,
#       'windchill_f': 46.5,
#       'heatindex_c': 10.4,
#       'heatindex_f': 50.7,
#       'dewpoint_c': 5.1,
#       'dewpoint_f': 41.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.9,
#       'gust_kph': 25.5,
#       'uv': 4.0},
#      {'time_epoch': 1700064000,
#       'time': '2023-11-15 16:00',
#       'temp_c': 9.6,
#       'temp_f': 49.3,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.1,
#       'wind_kph': 16.2,
#       'wind_degree': 263,
#       'wind_dir': 'W',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.07,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 73,
#       'cloud': 13,
#       'feelslike_c': 7.3,
#       'feelslike_f': 45.2,
#       'windchill_c': 7.3,
#       'windchill_f': 45.2,
#       'heatindex_c': 9.6,
#       'heatindex_f': 49.3,
#       'dewpoint_c': 5.1,
#       'dewpoint_f': 41.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.9,
#       'gust_kph': 24.0,
#       'uv': 3.0},
#      {'time_epoch': 1700067600,
#       'time': '2023-11-15 17:00',
#       'temp_c': 8.9,
#       'temp_f': 48.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 8.3,
#       'wind_kph': 13.3,
#       'wind_degree': 256,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.08,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 12,
#       'feelslike_c': 6.8,
#       'feelslike_f': 44.2,
#       'windchill_c': 6.8,
#       'windchill_f': 44.2,
#       'heatindex_c': 8.9,
#       'heatindex_f': 48.0,
#       'dewpoint_c': 5.0,
#       'dewpoint_f': 41.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.9,
#       'gust_kph': 20.8,
#       'uv': 1.0},
#      {'time_epoch': 1700071200,
#       'time': '2023-11-15 18:00',
#       'temp_c': 8.6,
#       'temp_f': 47.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 249,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.08,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 11,
#       'feelslike_c': 6.3,
#       'feelslike_f': 43.3,
#       'windchill_c': 6.3,
#       'windchill_f': 43.3,
#       'heatindex_c': 8.6,
#       'heatindex_f': 47.5,
#       'dewpoint_c': 5.1,
#       'dewpoint_f': 41.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.8,
#       'gust_kph': 22.2,
#       'uv': 1.0},
#      {'time_epoch': 1700074800,
#       'time': '2023-11-15 19:00',
#       'temp_c': 8.3,
#       'temp_f': 47.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 255,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.08,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 23,
#       'feelslike_c': 5.9,
#       'feelslike_f': 42.6,
#       'windchill_c': 5.9,
#       'windchill_f': 42.6,
#       'heatindex_c': 8.3,
#       'heatindex_f': 47.0,
#       'dewpoint_c': 5.1,
#       'dewpoint_f': 41.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.1,
#       'gust_kph': 22.7,
#       'uv': 1.0},
#      {'time_epoch': 1700078400,
#       'time': '2023-11-15 20:00',
#       'temp_c': 8.1,
#       'temp_f': 46.5,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 259,
#       'wind_dir': 'W',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.07,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 68,
#       'feelslike_c': 5.9,
#       'feelslike_f': 42.6,
#       'windchill_c': 5.9,
#       'windchill_f': 42.6,
#       'heatindex_c': 8.1,
#       'heatindex_f': 46.5,
#       'dewpoint_c': 4.9,
#       'dewpoint_f': 40.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.0,
#       'gust_kph': 19.3,
#       'uv': 1.0},
#      {'time_epoch': 1700082000,
#       'time': '2023-11-15 21:00',
#       'temp_c': 7.8,
#       'temp_f': 46.1,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 6.0,
#       'wind_kph': 9.7,
#       'wind_degree': 263,
#       'wind_dir': 'W',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.07,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 72,
#       'feelslike_c': 6.1,
#       'feelslike_f': 42.9,
#       'windchill_c': 6.1,
#       'windchill_f': 42.9,
#       'heatindex_c': 7.8,
#       'heatindex_f': 46.1,
#       'dewpoint_c': 4.6,
#       'dewpoint_f': 40.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.4,
#       'gust_kph': 15.1,
#       'uv': 1.0},
#      {'time_epoch': 1700085600,
#       'time': '2023-11-15 22:00',
#       'temp_c': 7.6,
#       'temp_f': 45.6,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 5.1,
#       'wind_kph': 8.3,
#       'wind_degree': 261,
#       'wind_dir': 'W',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 81,
#       'cloud': 57,
#       'feelslike_c': 6.1,
#       'feelslike_f': 42.9,
#       'windchill_c': 6.1,
#       'windchill_f': 42.9,
#       'heatindex_c': 7.6,
#       'heatindex_f': 45.6,
#       'dewpoint_c': 4.5,
#       'dewpoint_f': 40.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.1,
#       'gust_kph': 13.0,
#       'uv': 1.0},
#      {'time_epoch': 1700089200,
#       'time': '2023-11-15 23:00',
#       'temp_c': 7.1,
#       'temp_f': 44.8,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 5.1,
#       'wind_kph': 8.3,
#       'wind_degree': 243,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 63,
#       'feelslike_c': 5.5,
#       'feelslike_f': 42.0,
#       'windchill_c': 5.5,
#       'windchill_f': 42.0,
#       'heatindex_c': 7.1,
#       'heatindex_f': 44.8,
#       'dewpoint_c': 4.3,
#       'dewpoint_f': 39.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.4,
#       'gust_kph': 13.5,
#       'uv': 1.0}]},
#    {'date': '2023-11-16',
#     'date_epoch': 1700092800,
#     'day': {'maxtemp_c': 11.4,
#      'maxtemp_f': 52.5,
#      'mintemp_c': 5.5,
#      'mintemp_f': 41.8,
#      'avgtemp_c': 7.8,
#      'avgtemp_f': 46.0,
#      'maxwind_mph': 22.6,
#      'maxwind_kph': 36.4,
#      'totalprecip_mm': 15.88,
#      'totalprecip_in': 0.63,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 6.6,
#      'avgvis_miles': 4.0,
#      'avghumidity': 89.0,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 84,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Moderate rain',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png',
#       'code': 1189},
#      'uv': 2.0},
#     'astro': {'sunrise': '07:21 AM',
#      'sunset': '04:11 PM',
#      'moonrise': '11:21 AM',
#      'moonset': '05:55 PM',
#      'moon_phase': 'Waxing Crescent',
#      'moon_illumination': 8,
#      'is_moon_up': 0,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1700092800,
#       'time': '2023-11-16 00:00',
#       'temp_c': 6.7,
#       'temp_f': 44.0,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 252,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 84,
#       'cloud': 93,
#       'feelslike_c': 5.7,
#       'feelslike_f': 42.3,
#       'windchill_c': 5.7,
#       'windchill_f': 42.3,
#       'heatindex_c': 6.7,
#       'heatindex_f': 44.0,
#       'dewpoint_c': 4.1,
#       'dewpoint_f': 39.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.1,
#       'gust_kph': 9.9,
#       'uv': 1.0},
#      {'time_epoch': 1700096400,
#       'time': '2023-11-16 01:00',
#       'temp_c': 6.6,
#       'temp_f': 43.8,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 242,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 84,
#       'cloud': 35,
#       'feelslike_c': 5.7,
#       'feelslike_f': 42.3,
#       'windchill_c': 5.7,
#       'windchill_f': 42.3,
#       'heatindex_c': 6.6,
#       'heatindex_f': 43.8,
#       'dewpoint_c': 4.1,
#       'dewpoint_f': 39.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.7,
#       'gust_kph': 9.2,
#       'uv': 1.0},
#      {'time_epoch': 1700100000,
#       'time': '2023-11-16 02:00',
#       'temp_c': 6.7,
#       'temp_f': 44.1,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 0.7,
#       'wind_kph': 1.1,
#       'wind_degree': 174,
#       'wind_dir': 'S',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 83,
#       'cloud': 97,
#       'feelslike_c': 6.7,
#       'feelslike_f': 44.1,
#       'windchill_c': 6.7,
#       'windchill_f': 44.1,
#       'heatindex_c': 6.7,
#       'heatindex_f': 44.1,
#       'dewpoint_c': 4.0,
#       'dewpoint_f': 39.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 1.1,
#       'gust_kph': 1.8,
#       'uv': 1.0},
#      {'time_epoch': 1700103600,
#       'time': '2023-11-16 03:00',
#       'temp_c': 6.9,
#       'temp_f': 44.4,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 143,
#       'wind_dir': 'SE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 96,
#       'feelslike_c': 6.3,
#       'feelslike_f': 43.4,
#       'windchill_c': 6.3,
#       'windchill_f': 43.4,
#       'heatindex_c': 6.9,
#       'heatindex_f': 44.3,
#       'dewpoint_c': 4.0,
#       'dewpoint_f': 39.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.8,
#       'gust_kph': 7.7,
#       'uv': 1.0},
#      {'time_epoch': 1700107200,
#       'time': '2023-11-16 04:00',
#       'temp_c': 7.0,
#       'temp_f': 44.5,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 107,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.07,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 99,
#       'feelslike_c': 6.0,
#       'feelslike_f': 42.7,
#       'windchill_c': 6.0,
#       'windchill_f': 42.7,
#       'heatindex_c': 7.0,
#       'heatindex_f': 44.5,
#       'dewpoint_c': 4.1,
#       'dewpoint_f': 39.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 67,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.1,
#       'gust_kph': 9.9,
#       'uv': 1.0},
#      {'time_epoch': 1700110800,
#       'time': '2023-11-16 05:00',
#       'temp_c': 6.9,
#       'temp_f': 44.5,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 59,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.9,
#       'precip_mm': 0.14,
#       'precip_in': 0.01,
#       'humidity': 82,
#       'cloud': 100,
#       'feelslike_c': 5.6,
#       'feelslike_f': 42.1,
#       'windchill_c': 5.6,
#       'windchill_f': 42.1,
#       'heatindex_c': 7.0,
#       'heatindex_f': 44.5,
#       'dewpoint_c': 4.1,
#       'dewpoint_f': 39.4,
#       'will_it_rain': 1,
#       'chance_of_rain': 76,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.2,
#       'gust_kph': 11.6,
#       'uv': 1.0},
#      {'time_epoch': 1700114400,
#       'time': '2023-11-16 06:00',
#       'temp_c': 6.9,
#       'temp_f': 44.5,
#       'is_day': 0,
#       'condition': {'text': 'Patchy light drizzle',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/263.png',
#        'code': 1150},
#       'wind_mph': 6.9,
#       'wind_kph': 11.2,
#       'wind_degree': 87,
#       'wind_dir': 'E',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.19,
#       'precip_in': 0.01,
#       'humidity': 83,
#       'cloud': 71,
#       'feelslike_c': 4.8,
#       'feelslike_f': 40.6,
#       'windchill_c': 4.8,
#       'windchill_f': 40.6,
#       'heatindex_c': 6.9,
#       'heatindex_f': 44.5,
#       'dewpoint_c': 4.3,
#       'dewpoint_f': 39.7,
#       'will_it_rain': 1,
#       'chance_of_rain': 72,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 5.0,
#       'vis_miles': 3.0,
#       'gust_mph': 10.6,
#       'gust_kph': 17.0,
#       'uv': 1.0},
#      {'time_epoch': 1700118000,
#       'time': '2023-11-16 07:00',
#       'temp_c': 7.1,
#       'temp_f': 44.7,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 6.7,
#       'wind_kph': 10.8,
#       'wind_degree': 91,
#       'wind_dir': 'E',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.82,
#       'precip_mm': 0.42,
#       'precip_in': 0.02,
#       'humidity': 81,
#       'cloud': 89,
#       'feelslike_c': 5.0,
#       'feelslike_f': 40.9,
#       'windchill_c': 5.0,
#       'windchill_f': 40.9,
#       'heatindex_c': 7.1,
#       'heatindex_f': 44.7,
#       'dewpoint_c': 4.0,
#       'dewpoint_f': 39.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 62,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 9.8,
#       'gust_kph': 15.7,
#       'uv': 1.0},
#      {'time_epoch': 1700121600,
#       'time': '2023-11-16 08:00',
#       'temp_c': 7.0,
#       'temp_f': 44.5,
#       'is_day': 1,
#       'condition': {'text': 'Light rain',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/296.png',
#        'code': 1183},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 73,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.79,
#       'precip_mm': 0.81,
#       'precip_in': 0.03,
#       'humidity': 83,
#       'cloud': 93,
#       'feelslike_c': 4.3,
#       'feelslike_f': 39.7,
#       'windchill_c': 4.3,
#       'windchill_f': 39.7,
#       'heatindex_c': 7.0,
#       'heatindex_f': 44.5,
#       'dewpoint_c': 4.2,
#       'dewpoint_f': 39.6,
#       'will_it_rain': 1,
#       'chance_of_rain': 85,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 12.7,
#       'gust_kph': 20.4,
#       'uv': 2.0},
#      {'time_epoch': 1700125200,
#       'time': '2023-11-16 09:00',
#       'temp_c': 7.0,
#       'temp_f': 44.6,
#       'is_day': 1,
#       'condition': {'text': 'Light drizzle',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/266.png',
#        'code': 1153},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 71,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1008.0,
#       'pressure_in': 29.77,
#       'precip_mm': 0.63,
#       'precip_in': 0.02,
#       'humidity': 85,
#       'cloud': 100,
#       'feelslike_c': 4.1,
#       'feelslike_f': 39.4,
#       'windchill_c': 4.1,
#       'windchill_f': 39.4,
#       'heatindex_c': 7.0,
#       'heatindex_f': 44.6,
#       'dewpoint_c': 4.7,
#       'dewpoint_f': 40.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 84,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 2.0,
#       'vis_miles': 1.0,
#       'gust_mph': 13.7,
#       'gust_kph': 22.1,
#       'uv': 2.0},
#      {'time_epoch': 1700128800,
#       'time': '2023-11-16 10:00',
#       'temp_c': 7.1,
#       'temp_f': 44.7,
#       'is_day': 1,
#       'condition': {'text': 'Light rain',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/296.png',
#        'code': 1183},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 63,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.74,
#       'precip_mm': 0.95,
#       'precip_in': 0.04,
#       'humidity': 88,
#       'cloud': 100,
#       'feelslike_c': 4.1,
#       'feelslike_f': 39.4,
#       'windchill_c': 4.1,
#       'windchill_f': 39.4,
#       'heatindex_c': 7.1,
#       'heatindex_f': 44.7,
#       'dewpoint_c': 5.3,
#       'dewpoint_f': 41.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 84,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 14.5,
#       'gust_kph': 23.3,
#       'uv': 2.0},
#      {'time_epoch': 1700132400,
#       'time': '2023-11-16 11:00',
#       'temp_c': 7.5,
#       'temp_f': 45.5,
#       'is_day': 1,
#       'condition': {'text': 'Light rain',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/296.png',
#        'code': 1183},
#       'wind_mph': 10.1,
#       'wind_kph': 16.2,
#       'wind_degree': 54,
#       'wind_dir': 'NE',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 1.52,
#       'precip_in': 0.06,
#       'humidity': 91,
#       'cloud': 100,
#       'feelslike_c': 4.6,
#       'feelslike_f': 40.4,
#       'windchill_c': 4.6,
#       'windchill_f': 40.4,
#       'heatindex_c': 7.5,
#       'heatindex_f': 45.4,
#       'dewpoint_c': 6.2,
#       'dewpoint_f': 43.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 84,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 14.5,
#       'gust_kph': 23.4,
#       'uv': 2.0},
#      {'time_epoch': 1700136000,
#       'time': '2023-11-16 12:00',
#       'temp_c': 7.7,
#       'temp_f': 45.8,
#       'is_day': 1,
#       'condition': {'text': 'Light rain',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/296.png',
#        'code': 1183},
#       'wind_mph': 9.4,
#       'wind_kph': 15.1,
#       'wind_degree': 31,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 2.38,
#       'precip_in': 0.09,
#       'humidity': 91,
#       'cloud': 100,
#       'feelslike_c': 5.0,
#       'feelslike_f': 41.0,
#       'windchill_c': 5.0,
#       'windchill_f': 41.0,
#       'heatindex_c': 7.7,
#       'heatindex_f': 45.8,
#       'dewpoint_c': 6.3,
#       'dewpoint_f': 43.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 83,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 13.3,
#       'gust_kph': 21.5,
#       'uv': 2.0},
#      {'time_epoch': 1700139600,
#       'time': '2023-11-16 13:00',
#       'temp_c': 7.5,
#       'temp_f': 45.5,
#       'is_day': 1,
#       'condition': {'text': 'Light rain',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/296.png',
#        'code': 1183},
#       'wind_mph': 11.2,
#       'wind_kph': 18.0,
#       'wind_degree': 20,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 1.51,
#       'precip_in': 0.06,
#       'humidity': 91,
#       'cloud': 100,
#       'feelslike_c': 4.5,
#       'feelslike_f': 40.0,
#       'windchill_c': 4.5,
#       'windchill_f': 40.0,
#       'heatindex_c': 7.5,
#       'heatindex_f': 45.5,
#       'dewpoint_c': 6.2,
#       'dewpoint_f': 43.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 83,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 16.0,
#       'gust_kph': 25.7,
#       'uv': 2.0},
#      {'time_epoch': 1700143200,
#       'time': '2023-11-16 14:00',
#       'temp_c': 7.4,
#       'temp_f': 45.3,
#       'is_day': 1,
#       'condition': {'text': 'Light drizzle',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/266.png',
#        'code': 1153},
#       'wind_mph': 11.6,
#       'wind_kph': 18.7,
#       'wind_degree': 8,
#       'wind_dir': 'N',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.74,
#       'precip_mm': 0.73,
#       'precip_in': 0.03,
#       'humidity': 89,
#       'cloud': 100,
#       'feelslike_c': 4.3,
#       'feelslike_f': 39.7,
#       'windchill_c': 4.3,
#       'windchill_f': 39.7,
#       'heatindex_c': 7.4,
#       'heatindex_f': 45.3,
#       'dewpoint_c': 5.8,
#       'dewpoint_f': 42.4,
#       'will_it_rain': 1,
#       'chance_of_rain': 83,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 2.0,
#       'vis_miles': 1.0,
#       'gust_mph': 16.4,
#       'gust_kph': 26.4,
#       'uv': 2.0},
#      {'time_epoch': 1700146800,
#       'time': '2023-11-16 15:00',
#       'temp_c': 7.2,
#       'temp_f': 45.0,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 11.2,
#       'wind_kph': 18.0,
#       'wind_degree': 349,
#       'wind_dir': 'N',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.78,
#       'precip_mm': 0.37,
#       'precip_in': 0.01,
#       'humidity': 88,
#       'cloud': 100,
#       'feelslike_c': 4.1,
#       'feelslike_f': 39.4,
#       'windchill_c': 4.1,
#       'windchill_f': 39.4,
#       'heatindex_c': 7.2,
#       'heatindex_f': 45.0,
#       'dewpoint_c': 5.4,
#       'dewpoint_f': 41.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 64,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.6,
#       'gust_kph': 25.1,
#       'uv': 2.0},
#      {'time_epoch': 1700150400,
#       'time': '2023-11-16 16:00',
#       'temp_c': 7.1,
#       'temp_f': 44.8,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 336,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.82,
#       'precip_mm': 0.05,
#       'precip_in': 0.0,
#       'humidity': 87,
#       'cloud': 100,
#       'feelslike_c': 4.1,
#       'feelslike_f': 39.4,
#       'windchill_c': 4.1,
#       'windchill_f': 39.4,
#       'heatindex_c': 7.1,
#       'heatindex_f': 44.8,
#       'dewpoint_c': 5.2,
#       'dewpoint_f': 41.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 81,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.6,
#       'gust_kph': 23.5,
#       'uv': 2.0},
#      {'time_epoch': 1700154000,
#       'time': '2023-11-16 17:00',
#       'temp_c': 7.0,
#       'temp_f': 44.6,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 328,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.86,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'humidity': 87,
#       'cloud': 75,
#       'feelslike_c': 4.0,
#       'feelslike_f': 39.2,
#       'windchill_c': 4.0,
#       'windchill_f': 39.2,
#       'heatindex_c': 7.0,
#       'heatindex_f': 44.6,
#       'dewpoint_c': 5.1,
#       'dewpoint_f': 41.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 75,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.4,
#       'gust_kph': 23.1,
#       'uv': 1.0},
#      {'time_epoch': 1700157600,
#       'time': '2023-11-16 18:00',
#       'temp_c': 6.7,
#       'temp_f': 44.1,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 322,
#       'wind_dir': 'NW',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.88,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 87,
#       'cloud': 89,
#       'feelslike_c': 4.0,
#       'feelslike_f': 39.1,
#       'windchill_c': 4.0,
#       'windchill_f': 39.1,
#       'heatindex_c': 6.7,
#       'heatindex_f': 44.1,
#       'dewpoint_c': 4.7,
#       'dewpoint_f': 40.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.8,
#       'gust_kph': 20.5,
#       'uv': 1.0},
#      {'time_epoch': 1700161200,
#       'time': '2023-11-16 19:00',
#       'temp_c': 6.2,
#       'temp_f': 43.2,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 303,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.9,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 89,
#       'cloud': 35,
#       'feelslike_c': 3.8,
#       'feelslike_f': 38.9,
#       'windchill_c': 3.8,
#       'windchill_f': 38.9,
#       'heatindex_c': 6.2,
#       'heatindex_f': 43.2,
#       'dewpoint_c': 4.5,
#       'dewpoint_f': 40.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.7,
#       'gust_kph': 17.2,
#       'uv': 1.0},
#      {'time_epoch': 1700164800,
#       'time': '2023-11-16 20:00',
#       'temp_c': 6.3,
#       'temp_f': 43.4,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 7.4,
#       'wind_kph': 11.9,
#       'wind_degree': 267,
#       'wind_dir': 'W',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.93,
#       'precip_mm': 0.03,
#       'precip_in': 0.0,
#       'humidity': 89,
#       'cloud': 99,
#       'feelslike_c': 3.9,
#       'feelslike_f': 39.0,
#       'windchill_c': 3.9,
#       'windchill_f': 39.0,
#       'heatindex_c': 6.3,
#       'heatindex_f': 43.4,
#       'dewpoint_c': 4.7,
#       'dewpoint_f': 40.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 65,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.5,
#       'gust_kph': 16.9,
#       'uv': 1.0},
#      {'time_epoch': 1700168400,
#       'time': '2023-11-16 21:00',
#       'temp_c': 6.3,
#       'temp_f': 43.3,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 254,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.06,
#       'precip_in': 0.0,
#       'humidity': 88,
#       'cloud': 100,
#       'feelslike_c': 3.9,
#       'feelslike_f': 39.0,
#       'windchill_c': 3.9,
#       'windchill_f': 39.0,
#       'heatindex_c': 6.3,
#       'heatindex_f': 43.3,
#       'dewpoint_c': 4.5,
#       'dewpoint_f': 40.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 89,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.2,
#       'gust_kph': 16.4,
#       'uv': 1.0},
#      {'time_epoch': 1700172000,
#       'time': '2023-11-16 22:00',
#       'temp_c': 6.4,
#       'temp_f': 43.5,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 256,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 87,
#       'cloud': 99,
#       'feelslike_c': 4.3,
#       'feelslike_f': 39.7,
#       'windchill_c': 4.3,
#       'windchill_f': 39.7,
#       'heatindex_c': 6.4,
#       'heatindex_f': 43.4,
#       'dewpoint_c': 4.4,
#       'dewpoint_f': 39.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.7,
#       'gust_kph': 14.0,
#       'uv': 1.0},
#      {'time_epoch': 1700175600,
#       'time': '2023-11-16 23:00',
#       'temp_c': 5.9,
#       'temp_f': 42.7,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 6.0,
#       'wind_kph': 9.7,
#       'wind_degree': 253,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 89,
#       'cloud': 41,
#       'feelslike_c': 3.8,
#       'feelslike_f': 38.9,
#       'windchill_c': 3.8,
#       'windchill_f': 38.9,
#       'heatindex_c': 5.9,
#       'heatindex_f': 42.7,
#       'dewpoint_c': 4.2,
#       'dewpoint_f': 39.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.7,
#       'gust_kph': 14.1,
#       'uv': 1.0}]},
#    {'date': '2023-11-17',
#     'date_epoch': 1700179200,
#     'day': {'maxtemp_c': 8.5,
#      'maxtemp_f': 47.2,
#      'mintemp_c': 5.3,
#      'mintemp_f': 41.5,
#      'avgtemp_c': 6.5,
#      'avgtemp_f': 43.8,
#      'maxwind_mph': 13.0,
#      'maxwind_kph': 20.9,
#      'totalprecip_mm': 0.57,
#      'totalprecip_in': 0.02,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 9.7,
#      'avgvis_miles': 6.0,
#      'avghumidity': 86.0,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 88,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Patchy rain possible',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
# ...
#       'dewpoint_c': 3.9,
#       'dewpoint_f': 39.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 81,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.1,
#       'gust_kph': 17.9,
#       'uv': 1.0},
#      {'time_epoch': 1700204400,
#       'time': '2023-11-17 07:00',
#       'temp_c': 5.6,
#       'temp_f': 42.1,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 5.8,
#       'wind_kph': 9.4,
#       'wind_degree': 282,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 88,
#       'cloud': 83,
#       'feelslike_c': 3.5,
#       'feelslike_f': 38.4,
#       'windchill_c': 3.5,
#       'windchill_f': 38.4,
#       'heatindex_c': 5.6,
#       'heatindex_f': 42.1,
#       'dewpoint_c': 3.8,
#       'dewpoint_f': 38.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.7,
#       'gust_kph': 14.0,
#       'uv': 1.0},
#      {'time_epoch': 1700208000,
#       'time': '2023-11-17 08:00',
#       'temp_c': 5.6,
#       'temp_f': 42.2,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 6.0,
#       'wind_kph': 9.7,
#       'wind_degree': 282,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.07,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 88,
#       'cloud': 59,
#       'feelslike_c': 3.5,
#       'feelslike_f': 38.3,
#       'windchill_c': 3.5,
#       'windchill_f': 38.3,
#       'heatindex_c': 5.7,
#       'heatindex_f': 42.2,
#       'dewpoint_c': 3.8,
#       'dewpoint_f': 38.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.0,
#       'gust_kph': 14.5,
#       'uv': 3.0},
#      {'time_epoch': 1700211600,
#       'time': '2023-11-17 09:00',
#       'temp_c': 6.2,
#       'temp_f': 43.2,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 5.6,
#       'wind_kph': 9.0,
#       'wind_degree': 285,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.1,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 85,
#       'cloud': 41,
#       'feelslike_c': 4.3,
#       'feelslike_f': 39.8,
#       'windchill_c': 4.3,
#       'windchill_f': 39.8,
#       'heatindex_c': 6.2,
#       'heatindex_f': 43.2,
#       'dewpoint_c': 3.9,
#       'dewpoint_f': 39.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.9,
#       'gust_kph': 12.7,
#       'uv': 3.0},
#      {'time_epoch': 1700215200,
#       'time': '2023-11-17 10:00',
#       'temp_c': 7.1,
#       'temp_f': 44.7,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 292,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.11,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 81,
#       'cloud': 63,
#       'feelslike_c': 5.4,
#       'feelslike_f': 41.7,
#       'windchill_c': 5.4,
#       'windchill_f': 41.7,
#       'heatindex_c': 7.1,
#       'heatindex_f': 44.7,
#       'dewpoint_c': 4.0,
#       'dewpoint_f': 39.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.1,
#       'gust_kph': 11.4,
#       'uv': 2.0},
#      {'time_epoch': 1700218800,
#       'time': '2023-11-17 11:00',
#       'temp_c': 7.7,
#       'temp_f': 45.9,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 5.6,
#       'wind_kph': 9.0,
#       'wind_degree': 291,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.14,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 66,
#       'feelslike_c': 6.1,
#       'feelslike_f': 43.0,
#       'windchill_c': 6.1,
#       'windchill_f': 43.0,
#       'heatindex_c': 7.7,
#       'heatindex_f': 45.9,
#       'dewpoint_c': 4.0,
#       'dewpoint_f': 39.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.2,
#       'gust_kph': 11.7,
#       'uv': 2.0},
#      {'time_epoch': 1700222400,
#       'time': '2023-11-17 12:00',
#       'temp_c': 8.2,
#       'temp_f': 46.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 292,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.14,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 75,
#       'cloud': 28,
#       'feelslike_c': 6.8,
#       'feelslike_f': 44.2,
#       'windchill_c': 6.8,
#       'windchill_f': 44.2,
#       'heatindex_c': 8.2,
#       'heatindex_f': 46.8,
#       'dewpoint_c': 4.1,
#       'dewpoint_f': 39.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.9,
#       'gust_kph': 11.1,
#       'uv': 3.0},
#      {'time_epoch': 1700226000,
#       'time': '2023-11-17 13:00',
#       'temp_c': 8.8,
#       'temp_f': 47.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 5.6,
#       'wind_kph': 9.0,
#       'wind_degree': 290,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.16,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 73,
#       'cloud': 14,
#       'feelslike_c': 7.4,
#       'feelslike_f': 45.3,
#       'windchill_c': 7.4,
#       'windchill_f': 45.3,
#       'heatindex_c': 8.8,
#       'heatindex_f': 47.9,
#       'dewpoint_c': 4.3,
#       'dewpoint_f': 39.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.1,
#       'gust_kph': 11.4,
#       'uv': 3.0},
#      {'time_epoch': 1700229600,
#       'time': '2023-11-17 14:00',
#       'temp_c': 8.9,
#       'temp_f': 48.1,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 5.6,
#       'wind_kph': 9.0,
#       'wind_degree': 285,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.17,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 74,
#       'cloud': 44,
#       'feelslike_c': 7.6,
#       'feelslike_f': 45.6,
#       'windchill_c': 7.6,
#       'windchill_f': 45.6,
#       'heatindex_c': 8.9,
#       'heatindex_f': 48.1,
#       'dewpoint_c': 4.5,
#       'dewpoint_f': 40.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.4,
#       'gust_kph': 11.8,
#       'uv': 3.0},
#      {'time_epoch': 1700233200,
#       'time': '2023-11-17 15:00',
#       'temp_c': 8.6,
#       'temp_f': 47.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 285,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.18,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 78,
#       'cloud': 39,
#       'feelslike_c': 7.7,
#       'feelslike_f': 45.9,
#       'windchill_c': 7.7,
#       'windchill_f': 45.9,
#       'heatindex_c': 8.6,
#       'heatindex_f': 47.5,
#       'dewpoint_c': 5.0,
#       'dewpoint_f': 40.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.7,
#       'gust_kph': 9.1,
#       'uv': 3.0},
#      {'time_epoch': 1700236800,
#       'time': '2023-11-17 16:00',
#       'temp_c': 7.4,
#       'temp_f': 45.4,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 297,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.19,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 83,
#       'cloud': 25,
#       'feelslike_c': 6.8,
#       'feelslike_f': 44.3,
#       'windchill_c': 6.8,
#       'windchill_f': 44.3,
#       'heatindex_c': 7.4,
#       'heatindex_f': 45.4,
#       'dewpoint_c': 4.8,
#       'dewpoint_f': 40.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.2,
#       'gust_kph': 8.3,
#       'uv': 3.0},
#      {'time_epoch': 1700240400,
#       'time': '2023-11-17 17:00',
#       'temp_c': 6.9,
#       'temp_f': 44.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 2.0,
#       'wind_kph': 3.2,
#       'wind_degree': 285,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.2,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 85,
#       'cloud': 10,
#       'feelslike_c': 7.0,
#       'feelslike_f': 44.5,
#       'windchill_c': 7.0,
#       'windchill_f': 44.5,
#       'heatindex_c': 6.9,
#       'heatindex_f': 44.4,
#       'dewpoint_c': 4.6,
#       'dewpoint_f': 40.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.5,
#       'gust_kph': 5.6,
#       'uv': 1.0},
#      {'time_epoch': 1700244000,
#       'time': '2023-11-17 18:00',
#       'temp_c': 6.8,
#       'temp_f': 44.2,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 232,
#       'wind_dir': 'SW',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.2,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 86,
#       'cloud': 26,
#       'feelslike_c': 6.1,
#       'feelslike_f': 43.0,
#       'windchill_c': 6.1,
#       'windchill_f': 43.0,
#       'heatindex_c': 6.8,
#       'heatindex_f': 44.2,
#       'dewpoint_c': 4.6,
#       'dewpoint_f': 40.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.3,
#       'gust_kph': 8.6,
#       'uv': 1.0},
#      {'time_epoch': 1700247600,
#       'time': '2023-11-17 19:00',
#       'temp_c': 6.4,
#       'temp_f': 43.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 220,
#       'wind_dir': 'SW',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.21,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 87,
#       'cloud': 15,
#       'feelslike_c': 5.9,
#       'feelslike_f': 42.6,
#       'windchill_c': 5.9,
#       'windchill_f': 42.6,
#       'heatindex_c': 6.4,
#       'heatindex_f': 43.4,
#       'dewpoint_c': 4.4,
#       'dewpoint_f': 40.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.7,
#       'gust_kph': 7.6,
#       'uv': 1.0},
#      {'time_epoch': 1700251200,
#       'time': '2023-11-17 20:00',
#       'temp_c': 6.2,
#       'temp_f': 43.1,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 2.5,
#       'wind_kph': 4.0,
#       'wind_degree': 206,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.22,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 88,
#       'cloud': 73,
#       'feelslike_c': 5.8,
#       'feelslike_f': 42.5,
#       'windchill_c': 5.8,
#       'windchill_f': 42.5,
#       'heatindex_c': 6.2,
#       'heatindex_f': 43.1,
#       'dewpoint_c': 4.3,
#       'dewpoint_f': 39.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.3,
#       'gust_kph': 7.0,
#       'uv': 1.0},
#      {'time_epoch': 1700254800,
#       'time': '2023-11-17 21:00',
#       'temp_c': 6.1,
#       'temp_f': 43.1,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 183,
#       'wind_dir': 'S',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.22,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 88,
#       'cloud': 58,
#       'feelslike_c': 5.5,
#       'feelslike_f': 41.9,
#       'windchill_c': 5.5,
#       'windchill_f': 41.9,
#       'heatindex_c': 6.1,
#       'heatindex_f': 43.1,
#       'dewpoint_c': 4.2,
#       'dewpoint_f': 39.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.1,
#       'gust_kph': 8.2,
#       'uv': 1.0},
#      {'time_epoch': 1700258400,
#       'time': '2023-11-17 22:00',
#       'temp_c': 6.3,
#       'temp_f': 43.4,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 174,
#       'wind_dir': 'S',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.22,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 86,
#       'cloud': 54,
#       'feelslike_c': 5.7,
#       'feelslike_f': 42.3,
#       'windchill_c': 5.7,
#       'windchill_f': 42.3,
#       'heatindex_c': 6.3,
#       'heatindex_f': 43.4,
#       'dewpoint_c': 4.2,
#       'dewpoint_f': 39.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.9,
#       'gust_kph': 7.8,
#       'uv': 1.0},
#      {'time_epoch': 1700262000,
#       'time': '2023-11-17 23:00',
#       'temp_c': 6.4,
#       'temp_f': 43.6,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 159,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.21,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 85,
#       'cloud': 60,
#       'feelslike_c': 5.5,
#       'feelslike_f': 41.8,
#       'windchill_c': 5.5,
#       'windchill_f': 41.8,
#       'heatindex_c': 6.5,
#       'heatindex_f': 43.6,
#       'dewpoint_c': 4.2,
#       'dewpoint_f': 39.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.9,
#       'gust_kph': 9.5,
#       'uv': 1.0}]}]}}

# %%
data.keys()
# Out:
# dict_keys(['location', 'current', 'forecast'])

# %%
data['forecast'].keys()
# Out:
# dict_keys(['forecastday'])

# %%
data['forecast']['forecastday']
# Out:
# [{'date': '2023-11-15',
#   'date_epoch': 1700006400,
#   'day': {'maxtemp_c': 10.8,
#    'maxtemp_f': 51.5,
#    'mintemp_c': 7.1,
#    'mintemp_f': 44.9,
#    'avgtemp_c': 9.3,
#    'avgtemp_f': 48.7,
#    'maxwind_mph': 14.5,
#    'maxwind_kph': 23.4,
#    'totalprecip_mm': 0.21,
#    'totalprecip_in': 0.01,
#    'totalsnow_cm': 0.0,
#    'avgvis_km': 10.0,
#    'avgvis_miles': 6.0,
#    'avghumidity': 77.0,
#    'daily_will_it_rain': 1,
#    'daily_chance_of_rain': 87,
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': 0,
#    'condition': {'text': 'Patchy rain possible',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#     'code': 1063},
#    'uv': 2.0},
#   'astro': {'sunrise': '07:19 AM',
#    'sunset': '04:12 PM',
#    'moonrise': '10:10 AM',
#    'moonset': '05:01 PM',
#    'moon_phase': 'Waxing Crescent',
#    'moon_illumination': 3,
#    'is_moon_up': 0,
#    'is_sun_up': 0},
#   'hour': [{'time_epoch': 1700006400,
#     'time': '2023-11-15 00:00',
#     'temp_c': 10.6,
#     'temp_f': 51.1,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 12.3,
#     'wind_kph': 19.8,
#     'wind_degree': 259,
#     'wind_dir': 'W',
#     'pressure_mb': 1012.0,
#     'pressure_in': 29.89,
#     'precip_mm': 0.01,
#     'precip_in': 0.0,
#     'humidity': 79,
#     'cloud': 82,
#     'feelslike_c': 8.2,
#     'feelslike_f': 46.7,
#     'windchill_c': 8.2,
#     'windchill_f': 46.7,
#     'heatindex_c': 10.6,
#     'heatindex_f': 51.1,
#     'dewpoint_c': 7.2,
#     'dewpoint_f': 45.0,
#     'will_it_rain': 1,
#     'chance_of_rain': 72,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 18.7,
#     'gust_kph': 30.1,
#     'uv': 1.0},
#    {'time_epoch': 1700010000,
#     'time': '2023-11-15 01:00',
#     'temp_c': 9.7,
#     'temp_f': 49.5,
#     'is_day': 0,
#     'condition': {'text': 'Clear',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 11.4,
#     'wind_kph': 18.4,
#     'wind_degree': 258,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1013.0,
#     'pressure_in': 29.9,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 82,
#     'cloud': 12,
#     'feelslike_c': 7.2,
#     'feelslike_f': 45.0,
#     'windchill_c': 7.2,
#     'windchill_f': 45.0,
#     'heatindex_c': 9.8,
#     'heatindex_f': 49.6,
#     'dewpoint_c': 6.8,
#     'dewpoint_f': 44.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 18.1,
#     'gust_kph': 29.2,
#     'uv': 1.0},
#    {'time_epoch': 1700013600,
#     'time': '2023-11-15 02:00',
#     'temp_c': 9.2,
#     'temp_f': 48.5,
#     'is_day': 0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#      'code': 1006},
#     'wind_mph': 11.6,
#     'wind_kph': 18.7,
#     'wind_degree': 256,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1013.0,
#     'pressure_in': 29.92,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 89,
#     'cloud': 71,
#     'feelslike_c': 6.5,
#     'feelslike_f': 43.6,
#     'windchill_c': 6.5,
#     'windchill_f': 43.6,
#     'heatindex_c': 9.2,
#     'heatindex_f': 48.5,
#     'dewpoint_c': 7.5,
#     'dewpoint_f': 45.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 18.0,
#     'gust_kph': 28.9,
#     'uv': 1.0},
#    {'time_epoch': 1700017200,
#     'time': '2023-11-15 03:00',
#     'temp_c': 9.0,
#     'temp_f': 48.3,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 11.6,
#     'wind_kph': 18.7,
#     'wind_degree': 261,
#     'wind_dir': 'W',
#     'pressure_mb': 1014.0,
#     'pressure_in': 29.94,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 89,
#     'cloud': 62,
#     'feelslike_c': 6.3,
#     'feelslike_f': 43.3,
#     'windchill_c': 6.3,
#     'windchill_f': 43.3,
#     'heatindex_c': 9.0,
#     'heatindex_f': 48.3,
#     'dewpoint_c': 7.3,
#     'dewpoint_f': 45.1,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 17.9,
#     'gust_kph': 28.8,
#     'uv': 1.0},
#    {'time_epoch': 1700020800,
#     'time': '2023-11-15 04:00',
#     'temp_c': 9.0,
#     'temp_f': 48.2,
#     'is_day': 0,
#     'condition': {'text': 'Clear',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 11.9,
#     'wind_kph': 19.1,
#     'wind_degree': 250,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1013.0,
#     'pressure_in': 29.91,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 93,
#     'cloud': 0,
#     'feelslike_c': 6.1,
#     'feelslike_f': 43.0,
#     'windchill_c': 6.1,
#     'windchill_f': 43.0,
#     'heatindex_c': 8.8,
#     'heatindex_f': 47.9,
#     'dewpoint_c': 6.9,
#     'dewpoint_f': 44.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 16.9,
#     'gust_kph': 27.2,
#     'uv': 1.0},
#    {'time_epoch': 1700024400,
#     'time': '2023-11-15 05:00',
#     'temp_c': 8.6,
#     'temp_f': 47.5,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 11.2,
#     'wind_kph': 18.0,
#     'wind_degree': 261,
#     'wind_dir': 'W',
#     'pressure_mb': 1015.0,
#     'pressure_in': 29.98,
#     'precip_mm': 0.01,
#     'precip_in': 0.0,
#     'humidity': 88,
#     'cloud': 85,
#     'feelslike_c': 5.8,
#     'feelslike_f': 42.5,
#     'windchill_c': 5.8,
#     'windchill_f': 42.5,
#     'heatindex_c': 8.6,
#     'heatindex_f': 47.5,
#     'dewpoint_c': 6.7,
#     'dewpoint_f': 44.1,
#     'will_it_rain': 1,
#     'chance_of_rain': 84,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 17.2,
#     'gust_kph': 27.7,
#     'uv': 1.0},
#    {'time_epoch': 1700028000,
#     'time': '2023-11-15 06:00',
#     'temp_c': 8.8,
#     'temp_f': 47.9,
#     'is_day': 0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#      'code': 1006},
#     'wind_mph': 11.4,
#     'wind_kph': 18.4,
#     'wind_degree': 264,
#     'wind_dir': 'W',
#     'pressure_mb': 1016.0,
#     'pressure_in': 29.99,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 84,
#     'cloud': 70,
#     'feelslike_c': 6.1,
#     'feelslike_f': 42.9,
#     'windchill_c': 6.1,
#     'windchill_f': 42.9,
#     'heatindex_c': 8.8,
#     'heatindex_f': 47.9,
#     'dewpoint_c': 6.3,
#     'dewpoint_f': 43.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 17.4,
#     'gust_kph': 27.9,
#     'uv': 1.0},
#    {'time_epoch': 1700031600,
#     'time': '2023-11-15 07:00',
#     'temp_c': 8.6,
#     'temp_f': 47.5,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 11.2,
#     'wind_kph': 18.0,
#     'wind_degree': 261,
#     'wind_dir': 'W',
#     'pressure_mb': 1016.0,
#     'pressure_in': 30.0,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 82,
#     'cloud': 35,
#     'feelslike_c': 5.8,
#     'feelslike_f': 42.5,
#     'windchill_c': 5.8,
#     'windchill_f': 42.5,
#     'heatindex_c': 8.6,
#     'heatindex_f': 47.5,
#     'dewpoint_c': 5.8,
#     'dewpoint_f': 42.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 17.5,
#     'gust_kph': 28.1,
#     'uv': 1.0},
#    {'time_epoch': 1700035200,
#     'time': '2023-11-15 08:00',
#     'temp_c': 8.5,
#     'temp_f': 47.3,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 11.4,
#     'wind_kph': 18.4,
#     'wind_degree': 258,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.02,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 81,
#     'cloud': 24,
#     'feelslike_c': 5.7,
#     'feelslike_f': 42.2,
#     'windchill_c': 5.7,
#     'windchill_f': 42.2,
#     'heatindex_c': 8.5,
#     'heatindex_f': 47.3,
#     'dewpoint_c': 5.5,
#     'dewpoint_f': 41.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 17.8,
#     'gust_kph': 28.6,
#     'uv': 3.0},
#    {'time_epoch': 1700038800,
#     'time': '2023-11-15 09:00',
#     'temp_c': 9.1,
#     'temp_f': 48.5,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 11.6,
#     'wind_kph': 18.7,
#     'wind_degree': 258,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.04,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 80,
#     'cloud': 20,
#     'feelslike_c': 6.4,
#     'feelslike_f': 43.6,
#     'windchill_c': 6.4,
#     'windchill_f': 43.6,
#     'heatindex_c': 9.1,
#     'heatindex_f': 48.5,
#     'dewpoint_c': 5.9,
#     'dewpoint_f': 42.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 16.5,
#     'gust_kph': 26.6,
#     'uv': 3.0},
#    {'time_epoch': 1700042400,
#     'time': '2023-11-15 10:00',
#     'temp_c': 9.9,
#     'temp_f': 49.8,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 13.0,
#     'wind_kph': 20.9,
#     'wind_degree': 256,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.05,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 77,
#     'cloud': 34,
#     'feelslike_c': 7.2,
#     'feelslike_f': 44.9,
#     'windchill_c': 7.2,
#     'windchill_f': 44.9,
#     'heatindex_c': 9.9,
#     'heatindex_f': 49.8,
#     'dewpoint_c': 6.0,
#     'dewpoint_f': 42.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 17.0,
#     'gust_kph': 27.4,
#     'uv': 3.0},
#    {'time_epoch': 1700046000,
#     'time': '2023-11-15 11:00',
#     'temp_c': 10.6,
#     'temp_f': 51.1,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 12.5,
#     'wind_kph': 20.2,
#     'wind_degree': 261,
#     'wind_dir': 'W',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.05,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 72,
#     'cloud': 27,
#     'feelslike_c': 8.2,
#     'feelslike_f': 46.7,
#     'windchill_c': 8.2,
#     'windchill_f': 46.7,
#     'heatindex_c': 10.6,
#     'heatindex_f': 51.1,
#     'dewpoint_c': 5.9,
#     'dewpoint_f': 42.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 15.7,
#     'gust_kph': 25.2,
#     'uv': 4.0},
#    {'time_epoch': 1700049600,
#     'time': '2023-11-15 12:00',
#     'temp_c': 11.1,
#     'temp_f': 52.0,
#     'is_day': 1,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#      'code': 1063},
#     'wind_mph': 13.6,
#     'wind_kph': 22.0,
#     'wind_degree': 269,
#     'wind_dir': 'W',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.06,
#     'precip_mm': 0.02,
#     'precip_in': 0.0,
#     'humidity': 69,
#     'cloud': 83,
#     'feelslike_c': 8.6,
#     'feelslike_f': 47.5,
#     'windchill_c': 8.6,
#     'windchill_f': 47.5,
#     'heatindex_c': 11.1,
#     'heatindex_f': 52.0,
#     'dewpoint_c': 5.7,
#     'dewpoint_f': 42.3,
#     'will_it_rain': 1,
#     'chance_of_rain': 85,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 16.7,
#     'gust_kph': 26.9,
#     'uv': 3.0},
#    {'time_epoch': 1700053200,
#     'time': '2023-11-15 13:00',
#     'temp_c': 11.2,
#     'temp_f': 52.2,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 12.1,
#     'wind_kph': 19.4,
#     'wind_degree': 269,
#     'wind_dir': 'W',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.05,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 68,
#     'cloud': 18,
#     'feelslike_c': 8.9,
#     'feelslike_f': 48.1,
#     'windchill_c': 8.9,
#     'windchill_f': 48.1,
#     'heatindex_c': 11.2,
#     'heatindex_f': 52.2,
#     'dewpoint_c': 5.4,
#     'dewpoint_f': 41.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 14.9,
#     'gust_kph': 23.9,
#     'uv': 4.0},
#    {'time_epoch': 1700056800,
#     'time': '2023-11-15 14:00',
#     'temp_c': 11.0,
#     'temp_f': 51.9,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 11.9,
#     'wind_kph': 19.1,
#     'wind_degree': 265,
#     'wind_dir': 'W',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.05,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 67,
#     'cloud': 29,
#     'feelslike_c': 8.8,
#     'feelslike_f': 47.8,
#     'windchill_c': 8.8,
#     'windchill_f': 47.8,
#     'heatindex_c': 11.0,
#     'heatindex_f': 51.9,
#     'dewpoint_c': 5.2,
#     'dewpoint_f': 41.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 15.2,
#     'gust_kph': 24.5,
#     'uv': 4.0},
#    {'time_epoch': 1700060400,
#     'time': '2023-11-15 15:00',
#     'temp_c': 10.4,
#     'temp_f': 50.7,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 11.4,
#     'wind_kph': 18.4,
#     'wind_degree': 267,
#     'wind_dir': 'W',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.06,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 70,
#     'cloud': 40,
#     'feelslike_c': 8.0,
#     'feelslike_f': 46.5,
#     'windchill_c': 8.0,
#     'windchill_f': 46.5,
#     'heatindex_c': 10.4,
#     'heatindex_f': 50.7,
#     'dewpoint_c': 5.1,
#     'dewpoint_f': 41.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 15.9,
#     'gust_kph': 25.5,
#     'uv': 4.0},
#    {'time_epoch': 1700064000,
#     'time': '2023-11-15 16:00',
#     'temp_c': 9.6,
#     'temp_f': 49.3,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 10.1,
#     'wind_kph': 16.2,
#     'wind_degree': 263,
#     'wind_dir': 'W',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.07,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 73,
#     'cloud': 13,
#     'feelslike_c': 7.3,
#     'feelslike_f': 45.2,
#     'windchill_c': 7.3,
#     'windchill_f': 45.2,
#     'heatindex_c': 9.6,
#     'heatindex_f': 49.3,
#     'dewpoint_c': 5.1,
#     'dewpoint_f': 41.1,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 14.9,
#     'gust_kph': 24.0,
#     'uv': 3.0},
#    {'time_epoch': 1700067600,
#     'time': '2023-11-15 17:00',
#     'temp_c': 8.9,
#     'temp_f': 48.0,
#     'is_day': 0,
#     'condition': {'text': 'Clear',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 8.3,
#     'wind_kph': 13.3,
#     'wind_degree': 256,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.08,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 76,
#     'cloud': 12,
#     'feelslike_c': 6.8,
#     'feelslike_f': 44.2,
#     'windchill_c': 6.8,
#     'windchill_f': 44.2,
#     'heatindex_c': 8.9,
#     'heatindex_f': 48.0,
#     'dewpoint_c': 5.0,
#     'dewpoint_f': 41.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.9,
#     'gust_kph': 20.8,
#     'uv': 1.0},
#    {'time_epoch': 1700071200,
#     'time': '2023-11-15 18:00',
#     'temp_c': 8.6,
#     'temp_f': 47.5,
#     'is_day': 0,
#     'condition': {'text': 'Clear',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 8.9,
#     'wind_kph': 14.4,
#     'wind_degree': 249,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.08,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 79,
#     'cloud': 11,
#     'feelslike_c': 6.3,
#     'feelslike_f': 43.3,
#     'windchill_c': 6.3,
#     'windchill_f': 43.3,
#     'heatindex_c': 8.6,
#     'heatindex_f': 47.5,
#     'dewpoint_c': 5.1,
#     'dewpoint_f': 41.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 13.8,
#     'gust_kph': 22.2,
#     'uv': 1.0},
#    {'time_epoch': 1700074800,
#     'time': '2023-11-15 19:00',
#     'temp_c': 8.3,
#     'temp_f': 47.0,
#     'is_day': 0,
#     'condition': {'text': 'Clear',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 9.2,
#     'wind_kph': 14.8,
#     'wind_degree': 255,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.08,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 80,
#     'cloud': 23,
#     'feelslike_c': 5.9,
#     'feelslike_f': 42.6,
#     'windchill_c': 5.9,
#     'windchill_f': 42.6,
#     'heatindex_c': 8.3,
#     'heatindex_f': 47.0,
#     'dewpoint_c': 5.1,
#     'dewpoint_f': 41.1,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 14.1,
#     'gust_kph': 22.7,
#     'uv': 1.0},
#    {'time_epoch': 1700078400,
#     'time': '2023-11-15 20:00',
#     'temp_c': 8.1,
#     'temp_f': 46.5,
#     'is_day': 0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#      'code': 1006},
#     'wind_mph': 7.8,
#     'wind_kph': 12.6,
#     'wind_degree': 259,
#     'wind_dir': 'W',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.07,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 80,
#     'cloud': 68,
#     'feelslike_c': 5.9,
#     'feelslike_f': 42.6,
#     'windchill_c': 5.9,
#     'windchill_f': 42.6,
#     'heatindex_c': 8.1,
#     'heatindex_f': 46.5,
#     'dewpoint_c': 4.9,
#     'dewpoint_f': 40.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.0,
#     'gust_kph': 19.3,
#     'uv': 1.0},
#    {'time_epoch': 1700082000,
#     'time': '2023-11-15 21:00',
#     'temp_c': 7.8,
#     'temp_f': 46.1,
#     'is_day': 0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#      'code': 1006},
#     'wind_mph': 6.0,
#     'wind_kph': 9.7,
#     'wind_degree': 263,
#     'wind_dir': 'W',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.07,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 80,
#     'cloud': 72,
#     'feelslike_c': 6.1,
#     'feelslike_f': 42.9,
#     'windchill_c': 6.1,
#     'windchill_f': 42.9,
#     'heatindex_c': 7.8,
#     'heatindex_f': 46.1,
#     'dewpoint_c': 4.6,
#     'dewpoint_f': 40.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 9.4,
#     'gust_kph': 15.1,
#     'uv': 1.0},
#    {'time_epoch': 1700085600,
#     'time': '2023-11-15 22:00',
#     'temp_c': 7.6,
#     'temp_f': 45.6,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 5.1,
#     'wind_kph': 8.3,
#     'wind_degree': 261,
#     'wind_dir': 'W',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.06,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 81,
#     'cloud': 57,
#     'feelslike_c': 6.1,
#     'feelslike_f': 42.9,
#     'windchill_c': 6.1,
#     'windchill_f': 42.9,
#     'heatindex_c': 7.6,
#     'heatindex_f': 45.6,
#     'dewpoint_c': 4.5,
#     'dewpoint_f': 40.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.1,
#     'gust_kph': 13.0,
#     'uv': 1.0},
#    {'time_epoch': 1700089200,
#     'time': '2023-11-15 23:00',
#     'temp_c': 7.1,
#     'temp_f': 44.8,
#     'is_day': 0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#      'code': 1006},
#     'wind_mph': 5.1,
#     'wind_kph': 8.3,
#     'wind_degree': 243,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.06,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 82,
#     'cloud': 63,
#     'feelslike_c': 5.5,
#     'feelslike_f': 42.0,
#     'windchill_c': 5.5,
#     'windchill_f': 42.0,
#     'heatindex_c': 7.1,
#     'heatindex_f': 44.8,
#     'dewpoint_c': 4.3,
#     'dewpoint_f': 39.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.4,
#     'gust_kph': 13.5,
#     'uv': 1.0}]},
#  {'date': '2023-11-16',
#   'date_epoch': 1700092800,
#   'day': {'maxtemp_c': 11.4,
#    'maxtemp_f': 52.5,
#    'mintemp_c': 5.5,
#    'mintemp_f': 41.8,
#    'avgtemp_c': 7.8,
#    'avgtemp_f': 46.0,
#    'maxwind_mph': 22.6,
#    'maxwind_kph': 36.4,
#    'totalprecip_mm': 15.88,
#    'totalprecip_in': 0.63,
#    'totalsnow_cm': 0.0,
#    'avgvis_km': 6.6,
#    'avgvis_miles': 4.0,
#    'avghumidity': 89.0,
#    'daily_will_it_rain': 1,
#    'daily_chance_of_rain': 84,
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': 0,
#    'condition': {'text': 'Moderate rain',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png',
#     'code': 1189},
#    'uv': 2.0},
#   'astro': {'sunrise': '07:21 AM',
#    'sunset': '04:11 PM',
#    'moonrise': '11:21 AM',
#    'moonset': '05:55 PM',
#    'moon_phase': 'Waxing Crescent',
#    'moon_illumination': 8,
#    'is_moon_up': 0,
#    'is_sun_up': 0},
#   'hour': [{'time_epoch': 1700092800,
#     'time': '2023-11-16 00:00',
#     'temp_c': 6.7,
#     'temp_f': 44.0,
#     'is_day': 0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 252,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.04,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 84,
#     'cloud': 93,
#     'feelslike_c': 5.7,
#     'feelslike_f': 42.3,
#     'windchill_c': 5.7,
#     'windchill_f': 42.3,
#     'heatindex_c': 6.7,
#     'heatindex_f': 44.0,
#     'dewpoint_c': 4.1,
#     'dewpoint_f': 39.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.1,
#     'gust_kph': 9.9,
#     'uv': 1.0},
#    {'time_epoch': 1700096400,
#     'time': '2023-11-16 01:00',
#     'temp_c': 6.6,
#     'temp_f': 43.8,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 242,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.03,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 84,
#     'cloud': 35,
#     'feelslike_c': 5.7,
#     'feelslike_f': 42.3,
#     'windchill_c': 5.7,
#     'windchill_f': 42.3,
#     'heatindex_c': 6.6,
#     'heatindex_f': 43.8,
#     'dewpoint_c': 4.1,
#     'dewpoint_f': 39.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.7,
#     'gust_kph': 9.2,
#     'uv': 1.0},
#    {'time_epoch': 1700100000,
#     'time': '2023-11-16 02:00',
#     'temp_c': 6.7,
#     'temp_f': 44.1,
#     'is_day': 0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 0.7,
#     'wind_kph': 1.1,
#     'wind_degree': 174,
#     'wind_dir': 'S',
#     'pressure_mb': 1015.0,
#     'pressure_in': 29.99,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 83,
#     'cloud': 97,
#     'feelslike_c': 6.7,
#     'feelslike_f': 44.1,
#     'windchill_c': 6.7,
#     'windchill_f': 44.1,
#     'heatindex_c': 6.7,
#     'heatindex_f': 44.1,
#     'dewpoint_c': 4.0,
#     'dewpoint_f': 39.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 1.1,
#     'gust_kph': 1.8,
#     'uv': 1.0},
#    {'time_epoch': 1700103600,
#     'time': '2023-11-16 03:00',
#     'temp_c': 6.9,
#     'temp_f': 44.4,
#     'is_day': 0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 2.9,
#     'wind_kph': 4.7,
#     'wind_degree': 143,
#     'wind_dir': 'SE',
#     'pressure_mb': 1015.0,
#     'pressure_in': 29.96,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 82,
#     'cloud': 96,
#     'feelslike_c': 6.3,
#     'feelslike_f': 43.4,
#     'windchill_c': 6.3,
#     'windchill_f': 43.4,
#     'heatindex_c': 6.9,
#     'heatindex_f': 44.3,
#     'dewpoint_c': 4.0,
#     'dewpoint_f': 39.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.8,
#     'gust_kph': 7.7,
#     'uv': 1.0},
#    {'time_epoch': 1700107200,
#     'time': '2023-11-16 04:00',
#     'temp_c': 7.0,
#     'temp_f': 44.5,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 3.8,
#     'wind_kph': 6.1,
#     'wind_degree': 107,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1013.0,
#     'pressure_in': 29.91,
#     'precip_mm': 0.07,
#     'precip_in': 0.0,
#     'humidity': 82,
#     'cloud': 99,
#     'feelslike_c': 6.0,
#     'feelslike_f': 42.7,
#     'windchill_c': 6.0,
#     'windchill_f': 42.7,
#     'heatindex_c': 7.0,
#     'heatindex_f': 44.5,
#     'dewpoint_c': 4.1,
#     'dewpoint_f': 39.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 67,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.1,
#     'gust_kph': 9.9,
#     'uv': 1.0},
#    {'time_epoch': 1700110800,
#     'time': '2023-11-16 05:00',
#     'temp_c': 6.9,
#     'temp_f': 44.5,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 59,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1013.0,
#     'pressure_in': 29.9,
#     'precip_mm': 0.14,
#     'precip_in': 0.01,
#     'humidity': 82,
#     'cloud': 100,
#     'feelslike_c': 5.6,
#     'feelslike_f': 42.1,
#     'windchill_c': 5.6,
#     'windchill_f': 42.1,
#     'heatindex_c': 7.0,
#     'heatindex_f': 44.5,
#     'dewpoint_c': 4.1,
#     'dewpoint_f': 39.4,
#     'will_it_rain': 1,
#     'chance_of_rain': 76,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.2,
#     'gust_kph': 11.6,
#     'uv': 1.0},
#    {'time_epoch': 1700114400,
#     'time': '2023-11-16 06:00',
#     'temp_c': 6.9,
#     'temp_f': 44.5,
#     'is_day': 0,
#     'condition': {'text': 'Patchy light drizzle',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/263.png',
#      'code': 1150},
#     'wind_mph': 6.9,
#     'wind_kph': 11.2,
#     'wind_degree': 87,
#     'wind_dir': 'E',
#     'pressure_mb': 1011.0,
#     'pressure_in': 29.85,
#     'precip_mm': 0.19,
#     'precip_in': 0.01,
#     'humidity': 83,
#     'cloud': 71,
#     'feelslike_c': 4.8,
#     'feelslike_f': 40.6,
#     'windchill_c': 4.8,
#     'windchill_f': 40.6,
#     'heatindex_c': 6.9,
#     'heatindex_f': 44.5,
#     'dewpoint_c': 4.3,
#     'dewpoint_f': 39.7,
#     'will_it_rain': 1,
#     'chance_of_rain': 72,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 5.0,
#     'vis_miles': 3.0,
#     'gust_mph': 10.6,
#     'gust_kph': 17.0,
#     'uv': 1.0},
#    {'time_epoch': 1700118000,
#     'time': '2023-11-16 07:00',
#     'temp_c': 7.1,
#     'temp_f': 44.7,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 6.7,
#     'wind_kph': 10.8,
#     'wind_degree': 91,
#     'wind_dir': 'E',
#     'pressure_mb': 1010.0,
#     'pressure_in': 29.82,
#     'precip_mm': 0.42,
#     'precip_in': 0.02,
#     'humidity': 81,
#     'cloud': 89,
#     'feelslike_c': 5.0,
#     'feelslike_f': 40.9,
#     'windchill_c': 5.0,
#     'windchill_f': 40.9,
#     'heatindex_c': 7.1,
#     'heatindex_f': 44.7,
#     'dewpoint_c': 4.0,
#     'dewpoint_f': 39.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 62,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 9.0,
#     'vis_miles': 5.0,
#     'gust_mph': 9.8,
#     'gust_kph': 15.7,
#     'uv': 1.0},
#    {'time_epoch': 1700121600,
#     'time': '2023-11-16 08:00',
#     'temp_c': 7.0,
#     'temp_f': 44.5,
#     'is_day': 1,
#     'condition': {'text': 'Light rain',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/296.png',
#      'code': 1183},
#     'wind_mph': 8.9,
#     'wind_kph': 14.4,
#     'wind_degree': 73,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1009.0,
#     'pressure_in': 29.79,
#     'precip_mm': 0.81,
#     'precip_in': 0.03,
#     'humidity': 83,
#     'cloud': 93,
#     'feelslike_c': 4.3,
#     'feelslike_f': 39.7,
#     'windchill_c': 4.3,
#     'windchill_f': 39.7,
#     'heatindex_c': 7.0,
#     'heatindex_f': 44.5,
#     'dewpoint_c': 4.2,
#     'dewpoint_f': 39.6,
#     'will_it_rain': 1,
#     'chance_of_rain': 85,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 9.0,
#     'vis_miles': 5.0,
#     'gust_mph': 12.7,
#     'gust_kph': 20.4,
#     'uv': 2.0},
#    {'time_epoch': 1700125200,
#     'time': '2023-11-16 09:00',
#     'temp_c': 7.0,
#     'temp_f': 44.6,
#     'is_day': 1,
#     'condition': {'text': 'Light drizzle',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/266.png',
#      'code': 1153},
#     'wind_mph': 9.8,
#     'wind_kph': 15.8,
#     'wind_degree': 71,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1008.0,
#     'pressure_in': 29.77,
#     'precip_mm': 0.63,
#     'precip_in': 0.02,
#     'humidity': 85,
#     'cloud': 100,
#     'feelslike_c': 4.1,
#     'feelslike_f': 39.4,
#     'windchill_c': 4.1,
#     'windchill_f': 39.4,
#     'heatindex_c': 7.0,
#     'heatindex_f': 44.6,
#     'dewpoint_c': 4.7,
#     'dewpoint_f': 40.5,
#     'will_it_rain': 1,
#     'chance_of_rain': 84,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 2.0,
#     'vis_miles': 1.0,
#     'gust_mph': 13.7,
#     'gust_kph': 22.1,
#     'uv': 2.0},
#    {'time_epoch': 1700128800,
#     'time': '2023-11-16 10:00',
#     'temp_c': 7.1,
#     'temp_f': 44.7,
#     'is_day': 1,
#     'condition': {'text': 'Light rain',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/296.png',
#      'code': 1183},
#     'wind_mph': 10.3,
#     'wind_kph': 16.6,
#     'wind_degree': 63,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1007.0,
#     'pressure_in': 29.74,
#     'precip_mm': 0.95,
#     'precip_in': 0.04,
#     'humidity': 88,
#     'cloud': 100,
#     'feelslike_c': 4.1,
#     'feelslike_f': 39.4,
#     'windchill_c': 4.1,
#     'windchill_f': 39.4,
#     'heatindex_c': 7.1,
#     'heatindex_f': 44.7,
#     'dewpoint_c': 5.3,
#     'dewpoint_f': 41.5,
#     'will_it_rain': 1,
#     'chance_of_rain': 84,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 9.0,
#     'vis_miles': 5.0,
#     'gust_mph': 14.5,
#     'gust_kph': 23.3,
#     'uv': 2.0},
#    {'time_epoch': 1700132400,
#     'time': '2023-11-16 11:00',
#     'temp_c': 7.5,
#     'temp_f': 45.5,
#     'is_day': 1,
#     'condition': {'text': 'Light rain',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/296.png',
#      'code': 1183},
#     'wind_mph': 10.1,
#     'wind_kph': 16.2,
#     'wind_degree': 54,
#     'wind_dir': 'NE',
#     'pressure_mb': 1006.0,
#     'pressure_in': 29.71,
#     'precip_mm': 1.52,
#     'precip_in': 0.06,
#     'humidity': 91,
#     'cloud': 100,
#     'feelslike_c': 4.6,
#     'feelslike_f': 40.4,
#     'windchill_c': 4.6,
#     'windchill_f': 40.4,
#     'heatindex_c': 7.5,
#     'heatindex_f': 45.4,
#     'dewpoint_c': 6.2,
#     'dewpoint_f': 43.1,
#     'will_it_rain': 1,
#     'chance_of_rain': 84,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 9.0,
#     'vis_miles': 5.0,
#     'gust_mph': 14.5,
#     'gust_kph': 23.4,
#     'uv': 2.0},
#    {'time_epoch': 1700136000,
#     'time': '2023-11-16 12:00',
#     'temp_c': 7.7,
#     'temp_f': 45.8,
#     'is_day': 1,
#     'condition': {'text': 'Light rain',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/296.png',
#      'code': 1183},
#     'wind_mph': 9.4,
#     'wind_kph': 15.1,
#     'wind_degree': 31,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1006.0,
#     'pressure_in': 29.71,
#     'precip_mm': 2.38,
#     'precip_in': 0.09,
#     'humidity': 91,
#     'cloud': 100,
#     'feelslike_c': 5.0,
#     'feelslike_f': 41.0,
#     'windchill_c': 5.0,
#     'windchill_f': 41.0,
#     'heatindex_c': 7.7,
#     'heatindex_f': 45.8,
#     'dewpoint_c': 6.3,
#     'dewpoint_f': 43.3,
#     'will_it_rain': 1,
#     'chance_of_rain': 83,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 9.0,
#     'vis_miles': 5.0,
#     'gust_mph': 13.3,
#     'gust_kph': 21.5,
#     'uv': 2.0},
#    {'time_epoch': 1700139600,
#     'time': '2023-11-16 13:00',
#     'temp_c': 7.5,
#     'temp_f': 45.5,
#     'is_day': 1,
#     'condition': {'text': 'Light rain',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/296.png',
#      'code': 1183},
#     'wind_mph': 11.2,
#     'wind_kph': 18.0,
#     'wind_degree': 20,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1006.0,
#     'pressure_in': 29.71,
#     'precip_mm': 1.51,
#     'precip_in': 0.06,
#     'humidity': 91,
#     'cloud': 100,
#     'feelslike_c': 4.5,
#     'feelslike_f': 40.0,
#     'windchill_c': 4.5,
#     'windchill_f': 40.0,
#     'heatindex_c': 7.5,
#     'heatindex_f': 45.5,
#     'dewpoint_c': 6.2,
#     'dewpoint_f': 43.1,
#     'will_it_rain': 1,
#     'chance_of_rain': 83,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 9.0,
#     'vis_miles': 5.0,
#     'gust_mph': 16.0,
#     'gust_kph': 25.7,
#     'uv': 2.0},
#    {'time_epoch': 1700143200,
#     'time': '2023-11-16 14:00',
#     'temp_c': 7.4,
#     'temp_f': 45.3,
#     'is_day': 1,
#     'condition': {'text': 'Light drizzle',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/266.png',
#      'code': 1153},
#     'wind_mph': 11.6,
#     'wind_kph': 18.7,
#     'wind_degree': 8,
#     'wind_dir': 'N',
#     'pressure_mb': 1007.0,
#     'pressure_in': 29.74,
#     'precip_mm': 0.73,
#     'precip_in': 0.03,
#     'humidity': 89,
#     'cloud': 100,
#     'feelslike_c': 4.3,
#     'feelslike_f': 39.7,
#     'windchill_c': 4.3,
#     'windchill_f': 39.7,
#     'heatindex_c': 7.4,
#     'heatindex_f': 45.3,
#     'dewpoint_c': 5.8,
#     'dewpoint_f': 42.4,
#     'will_it_rain': 1,
#     'chance_of_rain': 83,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 2.0,
#     'vis_miles': 1.0,
#     'gust_mph': 16.4,
#     'gust_kph': 26.4,
#     'uv': 2.0},
#    {'time_epoch': 1700146800,
#     'time': '2023-11-16 15:00',
#     'temp_c': 7.2,
#     'temp_f': 45.0,
#     'is_day': 1,
#     'condition': {'text': 'Light rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#      'code': 1240},
#     'wind_mph': 11.2,
#     'wind_kph': 18.0,
#     'wind_degree': 349,
#     'wind_dir': 'N',
#     'pressure_mb': 1009.0,
#     'pressure_in': 29.78,
#     'precip_mm': 0.37,
#     'precip_in': 0.01,
#     'humidity': 88,
#     'cloud': 100,
#     'feelslike_c': 4.1,
#     'feelslike_f': 39.4,
#     'windchill_c': 4.1,
#     'windchill_f': 39.4,
#     'heatindex_c': 7.2,
#     'heatindex_f': 45.0,
#     'dewpoint_c': 5.4,
#     'dewpoint_f': 41.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 64,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 15.6,
#     'gust_kph': 25.1,
#     'uv': 2.0},
#    {'time_epoch': 1700150400,
#     'time': '2023-11-16 16:00',
#     'temp_c': 7.1,
#     'temp_f': 44.8,
#     'is_day': 1,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#      'code': 1063},
#     'wind_mph': 10.5,
#     'wind_kph': 16.9,
#     'wind_degree': 336,
#     'wind_dir': 'NNW',
#     'pressure_mb': 1010.0,
#     'pressure_in': 29.82,
#     'precip_mm': 0.05,
#     'precip_in': 0.0,
#     'humidity': 87,
#     'cloud': 100,
#     'feelslike_c': 4.1,
#     'feelslike_f': 39.4,
#     'windchill_c': 4.1,
#     'windchill_f': 39.4,
#     'heatindex_c': 7.1,
#     'heatindex_f': 44.8,
#     'dewpoint_c': 5.2,
#     'dewpoint_f': 41.3,
#     'will_it_rain': 1,
#     'chance_of_rain': 81,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 14.6,
#     'gust_kph': 23.5,
#     'uv': 2.0},
#    {'time_epoch': 1700154000,
#     'time': '2023-11-16 17:00',
#     'temp_c': 7.0,
#     'temp_f': 44.6,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 10.3,
#     'wind_kph': 16.6,
#     'wind_degree': 328,
#     'wind_dir': 'NNW',
#     'pressure_mb': 1011.0,
#     'pressure_in': 29.86,
#     'precip_mm': 0.01,
#     'precip_in': 0.0,
#     'humidity': 87,
#     'cloud': 75,
#     'feelslike_c': 4.0,
#     'feelslike_f': 39.2,
#     'windchill_c': 4.0,
#     'windchill_f': 39.2,
#     'heatindex_c': 7.0,
#     'heatindex_f': 44.6,
#     'dewpoint_c': 5.1,
#     'dewpoint_f': 41.1,
#     'will_it_rain': 1,
#     'chance_of_rain': 75,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 14.4,
#     'gust_kph': 23.1,
#     'uv': 1.0},
#    {'time_epoch': 1700157600,
#     'time': '2023-11-16 18:00',
#     'temp_c': 6.7,
#     'temp_f': 44.1,
#     'is_day': 0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 8.9,
#     'wind_kph': 14.4,
#     'wind_degree': 322,
#     'wind_dir': 'NW',
#     'pressure_mb': 1012.0,
#     'pressure_in': 29.88,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 87,
#     'cloud': 89,
#     'feelslike_c': 4.0,
#     'feelslike_f': 39.1,
#     'windchill_c': 4.0,
#     'windchill_f': 39.1,
#     'heatindex_c': 6.7,
#     'heatindex_f': 44.1,
#     'dewpoint_c': 4.7,
#     'dewpoint_f': 40.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 12.8,
#     'gust_kph': 20.5,
#     'uv': 1.0},
#    {'time_epoch': 1700161200,
#     'time': '2023-11-16 19:00',
#     'temp_c': 6.2,
#     'temp_f': 43.2,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 7.2,
#     'wind_kph': 11.5,
#     'wind_degree': 303,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1013.0,
#     'pressure_in': 29.9,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 89,
#     'cloud': 35,
#     'feelslike_c': 3.8,
#     'feelslike_f': 38.9,
#     'windchill_c': 3.8,
#     'windchill_f': 38.9,
#     'heatindex_c': 6.2,
#     'heatindex_f': 43.2,
#     'dewpoint_c': 4.5,
#     'dewpoint_f': 40.1,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 10.7,
#     'gust_kph': 17.2,
#     'uv': 1.0},
#    {'time_epoch': 1700164800,
#     'time': '2023-11-16 20:00',
#     'temp_c': 6.3,
#     'temp_f': 43.4,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 7.4,
#     'wind_kph': 11.9,
#     'wind_degree': 267,
#     'wind_dir': 'W',
#     'pressure_mb': 1013.0,
#     'pressure_in': 29.93,
#     'precip_mm': 0.03,
#     'precip_in': 0.0,
#     'humidity': 89,
#     'cloud': 99,
#     'feelslike_c': 3.9,
#     'feelslike_f': 39.0,
#     'windchill_c': 3.9,
#     'windchill_f': 39.0,
#     'heatindex_c': 6.3,
#     'heatindex_f': 43.4,
#     'dewpoint_c': 4.7,
#     'dewpoint_f': 40.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 65,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 10.5,
#     'gust_kph': 16.9,
#     'uv': 1.0},
#    {'time_epoch': 1700168400,
#     'time': '2023-11-16 21:00',
#     'temp_c': 6.3,
#     'temp_f': 43.3,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 7.2,
#     'wind_kph': 11.5,
#     'wind_degree': 254,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1014.0,
#     'pressure_in': 29.94,
#     'precip_mm': 0.06,
#     'precip_in': 0.0,
#     'humidity': 88,
#     'cloud': 100,
#     'feelslike_c': 3.9,
#     'feelslike_f': 39.0,
#     'windchill_c': 3.9,
#     'windchill_f': 39.0,
#     'heatindex_c': 6.3,
#     'heatindex_f': 43.3,
#     'dewpoint_c': 4.5,
#     'dewpoint_f': 40.1,
#     'will_it_rain': 1,
#     'chance_of_rain': 89,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 10.2,
#     'gust_kph': 16.4,
#     'uv': 1.0},
#    {'time_epoch': 1700172000,
#     'time': '2023-11-16 22:00',
#     'temp_c': 6.4,
#     'temp_f': 43.5,
#     'is_day': 0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 6.3,
#     'wind_kph': 10.1,
#     'wind_degree': 256,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1014.0,
#     'pressure_in': 29.94,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 87,
#     'cloud': 99,
#     'feelslike_c': 4.3,
#     'feelslike_f': 39.7,
#     'windchill_c': 4.3,
#     'windchill_f': 39.7,
#     'heatindex_c': 6.4,
#     'heatindex_f': 43.4,
#     'dewpoint_c': 4.4,
#     'dewpoint_f': 39.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.7,
#     'gust_kph': 14.0,
#     'uv': 1.0},
#    {'time_epoch': 1700175600,
#     'time': '2023-11-16 23:00',
#     'temp_c': 5.9,
#     'temp_f': 42.7,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 6.0,
#     'wind_kph': 9.7,
#     'wind_degree': 253,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1014.0,
#     'pressure_in': 29.95,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 89,
#     'cloud': 41,
#     'feelslike_c': 3.8,
#     'feelslike_f': 38.9,
#     'windchill_c': 3.8,
#     'windchill_f': 38.9,
#     'heatindex_c': 5.9,
#     'heatindex_f': 42.7,
#     'dewpoint_c': 4.2,
#     'dewpoint_f': 39.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.7,
#     'gust_kph': 14.1,
#     'uv': 1.0}]},
#  {'date': '2023-11-17',
#   'date_epoch': 1700179200,
#   'day': {'maxtemp_c': 8.5,
#    'maxtemp_f': 47.2,
#    'mintemp_c': 5.3,
#    'mintemp_f': 41.5,
#    'avgtemp_c': 6.5,
#    'avgtemp_f': 43.8,
#    'maxwind_mph': 13.0,
#    'maxwind_kph': 20.9,
#    'totalprecip_mm': 0.57,
#    'totalprecip_in': 0.02,
#    'totalsnow_cm': 0.0,
#    'avgvis_km': 9.7,
#    'avgvis_miles': 6.0,
#    'avghumidity': 86.0,
#    'daily_will_it_rain': 1,
#    'daily_chance_of_rain': 88,
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': 0,
#    'condition': {'text': 'Patchy rain possible',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#     'code': 1063},
#    'uv': 2.0},
#   'astro': {'sunrise': '07:22 AM',
#    'sunset': '04:10 PM',
#    'moonrise': '12:15 PM',
#    'moonset': '07:07 PM',
#    'moon_phase': 'Waxing Crescent',
#    'moon_illumination': 15,
#    'is_moon_up': 0,
#    'is_sun_up': 0},
#   'hour': [{'time_epoch': 1700179200,
#     'time': '2023-11-17 00:00',
#     'temp_c': 5.3,
#     'temp_f': 41.5,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 5.1,
#     'wind_kph': 8.3,
#     'wind_degree': 239,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1014.0,
#     'pressure_in': 29.94,
#     'precip_mm': 0.03,
#     'precip_in': 0.0,
#     'humidity': 92,
#     'cloud': 52,
#     'feelslike_c': 3.4,
#     'feelslike_f': 38.1,
#     'windchill_c': 3.4,
#     'windchill_f': 38.1,
#     'heatindex_c': 5.3,
#     'heatindex_f': 41.5,
#     'dewpoint_c': 4.1,
#     'dewpoint_f': 39.3,
#     'will_it_rain': 1,
#     'chance_of_rain': 80,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.0,
#     'gust_kph': 12.9,
#     'uv': 1.0},
#    {'time_epoch': 1700182800,
#     'time': '2023-11-17 01:00',
#     'temp_c': 5.5,
#     'temp_f': 41.9,
#     'is_day': 0,
#     'condition': {'text': 'Light drizzle',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/266.png',
#      'code': 1153},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 232,
#     'wind_dir': 'SW',
#     'pressure_mb': 1013.0,
#     'pressure_in': 29.93,
#     'precip_mm': 0.15,
#     'precip_in': 0.01,
#     'humidity': 92,
#     'cloud': 84,
#     'feelslike_c': 4.1,
#     'feelslike_f': 39.4,
#     'windchill_c': 4.1,
#     'windchill_f': 39.4,
#     'heatindex_c': 5.5,
#     'heatindex_f': 41.9,
#     'dewpoint_c': 4.4,
#     'dewpoint_f': 39.8,
#     'will_it_rain': 1,
#     'chance_of_rain': 89,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 2.0,
#     'vis_miles': 1.0,
#     'gust_mph': 6.1,
#     'gust_kph': 9.9,
#     'uv': 1.0},
#    {'time_epoch': 1700186400,
#     'time': '2023-11-17 02:00',
#     'temp_c': 5.7,
#     'temp_f': 42.3,
#     'is_day': 0,
#     'condition': {'text': 'Light rain',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/296.png',
#      'code': 1183},
#     'wind_mph': 4.9,
#     'wind_kph': 7.9,
#     'wind_degree': 270,
#     'wind_dir': 'W',
#     'pressure_mb': 1014.0,
#     'pressure_in': 29.94,
#     'precip_mm': 1.04,
#     'precip_in': 0.04,
#     'humidity': 94,
#     'cloud': 100,
#     'feelslike_c': 4.0,
#     'feelslike_f': 39.3,
#     'windchill_c': 4.0,
#     'windchill_f': 39.3,
#     'heatindex_c': 5.8,
#     'heatindex_f': 42.4,
#     'dewpoint_c': 4.8,
#     'dewpoint_f': 40.6,
#     'will_it_rain': 1,
#     'chance_of_rain': 78,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 9.0,
#     'vis_miles': 5.0,
#     'gust_mph': 7.1,
#     'gust_kph': 11.4,
#     'uv': 1.0},
#    {'time_epoch': 1700190000,
#     'time': '2023-11-17 03:00',
#     'temp_c': 6.1,
#     'temp_f': 43.0,
#     'is_day': 0,
#     'condition': {'text': 'Light drizzle',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/266.png',
#      'code': 1153},
#     'wind_mph': 7.4,
#     'wind_kph': 11.9,
#     'wind_degree': 294,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1014.0,
#     'pressure_in': 29.95,
#     'precip_mm': 0.34,
#     'precip_in': 0.01,
#     'humidity': 93,
#     'cloud': 100,
#     'feelslike_c': 3.6,
#     'feelslike_f': 38.5,
#     'windchill_c': 3.6,
#     'windchill_f': 38.5,
#     'heatindex_c': 6.1,
#     'heatindex_f': 43.0,
#     'dewpoint_c': 5.0,
#     'dewpoint_f': 41.0,
#     'will_it_rain': 1,
#     'chance_of_rain': 85,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 2.0,
#     'vis_miles': 1.0,
#     'gust_mph': 10.4,
#     'gust_kph': 16.7,
#     'uv': 1.0},
#    {'time_epoch': 1700193600,
#     'time': '2023-11-17 04:00',
#     'temp_c': 6.2,
#     'temp_f': 43.1,
#     'is_day': 0,
#     'condition': {'text': 'Overcast',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 9.2,
#     'wind_kph': 14.8,
#     'wind_degree': 292,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1015.0,
#     'pressure_in': 29.97,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 86,
#     'cloud': 100,
#     'feelslike_c': 3.3,
#     'feelslike_f': 37.9,
#     'windchill_c': 3.3,
#     'windchill_f': 37.9,
#     'heatindex_c': 6.2,
#     'heatindex_f': 43.1,
#     'dewpoint_c': 4.0,
#     'dewpoint_f': 39.2,
# ...
#     'wind_degree': 289,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1016.0,
#     'pressure_in': 29.99,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 86,
#     'cloud': 100,
#     'feelslike_c': 3.4,
#     'feelslike_f': 38.1,
#     'windchill_c': 3.4,
#     'windchill_f': 38.1,
#     'heatindex_c': 6.0,
#     'heatindex_f': 42.9,
#     'dewpoint_c': 3.9,
#     'dewpoint_f': 39.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.4,
#     'gust_kph': 18.3,
#     'uv': 1.0},
#    {'time_epoch': 1700200800,
#     'time': '2023-11-17 06:00',
#     'temp_c': 5.9,
#     'temp_f': 42.7,
#     'is_day': 0,
#     'condition': {'text': 'Patchy rain possible',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#      'code': 1063},
#     'wind_mph': 7.6,
#     'wind_kph': 12.2,
#     'wind_degree': 286,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.02,
#     'precip_mm': 0.01,
#     'precip_in': 0.0,
#     'humidity': 87,
#     'cloud': 84,
#     'feelslike_c': 3.3,
#     'feelslike_f': 38.0,
#     'windchill_c': 3.3,
#     'windchill_f': 38.0,
#     'heatindex_c': 5.9,
#     'heatindex_f': 42.7,
#     'dewpoint_c': 3.9,
#     'dewpoint_f': 39.1,
#     'will_it_rain': 1,
#     'chance_of_rain': 81,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.1,
#     'gust_kph': 17.9,
#     'uv': 1.0},
#    {'time_epoch': 1700204400,
#     'time': '2023-11-17 07:00',
#     'temp_c': 5.6,
#     'temp_f': 42.1,
#     'is_day': 0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#      'code': 1006},
#     'wind_mph': 5.8,
#     'wind_kph': 9.4,
#     'wind_degree': 282,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.03,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 88,
#     'cloud': 83,
#     'feelslike_c': 3.5,
#     'feelslike_f': 38.4,
#     'windchill_c': 3.5,
#     'windchill_f': 38.4,
#     'heatindex_c': 5.6,
#     'heatindex_f': 42.1,
#     'dewpoint_c': 3.8,
#     'dewpoint_f': 38.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.7,
#     'gust_kph': 14.0,
#     'uv': 1.0},
#    {'time_epoch': 1700208000,
#     'time': '2023-11-17 08:00',
#     'temp_c': 5.6,
#     'temp_f': 42.2,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 6.0,
#     'wind_kph': 9.7,
#     'wind_degree': 282,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.07,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 88,
#     'cloud': 59,
#     'feelslike_c': 3.5,
#     'feelslike_f': 38.3,
#     'windchill_c': 3.5,
#     'windchill_f': 38.3,
#     'heatindex_c': 5.7,
#     'heatindex_f': 42.2,
#     'dewpoint_c': 3.8,
#     'dewpoint_f': 38.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 9.0,
#     'gust_kph': 14.5,
#     'uv': 3.0},
#    {'time_epoch': 1700211600,
#     'time': '2023-11-17 09:00',
#     'temp_c': 6.2,
#     'temp_f': 43.2,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 5.6,
#     'wind_kph': 9.0,
#     'wind_degree': 285,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.1,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 85,
#     'cloud': 41,
#     'feelslike_c': 4.3,
#     'feelslike_f': 39.8,
#     'windchill_c': 4.3,
#     'windchill_f': 39.8,
#     'heatindex_c': 6.2,
#     'heatindex_f': 43.2,
#     'dewpoint_c': 3.9,
#     'dewpoint_f': 39.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.9,
#     'gust_kph': 12.7,
#     'uv': 3.0},
#    {'time_epoch': 1700215200,
#     'time': '2023-11-17 10:00',
#     'temp_c': 7.1,
#     'temp_f': 44.7,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 5.4,
#     'wind_kph': 8.6,
#     'wind_degree': 292,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.11,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 81,
#     'cloud': 63,
#     'feelslike_c': 5.4,
#     'feelslike_f': 41.7,
#     'windchill_c': 5.4,
#     'windchill_f': 41.7,
#     'heatindex_c': 7.1,
#     'heatindex_f': 44.7,
#     'dewpoint_c': 4.0,
#     'dewpoint_f': 39.1,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.1,
#     'gust_kph': 11.4,
#     'uv': 2.0},
#    {'time_epoch': 1700218800,
#     'time': '2023-11-17 11:00',
#     'temp_c': 7.7,
#     'temp_f': 45.9,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 5.6,
#     'wind_kph': 9.0,
#     'wind_degree': 291,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1021.0,
#     'pressure_in': 30.14,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 77,
#     'cloud': 66,
#     'feelslike_c': 6.1,
#     'feelslike_f': 43.0,
#     'windchill_c': 6.1,
#     'windchill_f': 43.0,
#     'heatindex_c': 7.7,
#     'heatindex_f': 45.9,
#     'dewpoint_c': 4.0,
#     'dewpoint_f': 39.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.2,
#     'gust_kph': 11.7,
#     'uv': 2.0},
#    {'time_epoch': 1700222400,
#     'time': '2023-11-17 12:00',
#     'temp_c': 8.2,
#     'temp_f': 46.8,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 5.4,
#     'wind_kph': 8.6,
#     'wind_degree': 292,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1021.0,
#     'pressure_in': 30.14,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 75,
#     'cloud': 28,
#     'feelslike_c': 6.8,
#     'feelslike_f': 44.2,
#     'windchill_c': 6.8,
#     'windchill_f': 44.2,
#     'heatindex_c': 8.2,
#     'heatindex_f': 46.8,
#     'dewpoint_c': 4.1,
#     'dewpoint_f': 39.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.9,
#     'gust_kph': 11.1,
#     'uv': 3.0},
#    {'time_epoch': 1700226000,
#     'time': '2023-11-17 13:00',
#     'temp_c': 8.8,
#     'temp_f': 47.9,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 5.6,
#     'wind_kph': 9.0,
#     'wind_degree': 290,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1021.0,
#     'pressure_in': 30.16,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 73,
#     'cloud': 14,
#     'feelslike_c': 7.4,
#     'feelslike_f': 45.3,
#     'windchill_c': 7.4,
#     'windchill_f': 45.3,
#     'heatindex_c': 8.8,
#     'heatindex_f': 47.9,
#     'dewpoint_c': 4.3,
#     'dewpoint_f': 39.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.1,
#     'gust_kph': 11.4,
#     'uv': 3.0},
#    {'time_epoch': 1700229600,
#     'time': '2023-11-17 14:00',
#     'temp_c': 8.9,
#     'temp_f': 48.1,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 5.6,
#     'wind_kph': 9.0,
#     'wind_degree': 285,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.17,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 74,
#     'cloud': 44,
#     'feelslike_c': 7.6,
#     'feelslike_f': 45.6,
#     'windchill_c': 7.6,
#     'windchill_f': 45.6,
#     'heatindex_c': 8.9,
#     'heatindex_f': 48.1,
#     'dewpoint_c': 4.5,
#     'dewpoint_f': 40.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.4,
#     'gust_kph': 11.8,
#     'uv': 3.0},
#    {'time_epoch': 1700233200,
#     'time': '2023-11-17 15:00',
#     'temp_c': 8.6,
#     'temp_f': 47.5,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 285,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.18,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 78,
#     'cloud': 39,
#     'feelslike_c': 7.7,
#     'feelslike_f': 45.9,
#     'windchill_c': 7.7,
#     'windchill_f': 45.9,
#     'heatindex_c': 8.6,
#     'heatindex_f': 47.5,
#     'dewpoint_c': 5.0,
#     'dewpoint_f': 40.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.7,
#     'gust_kph': 9.1,
#     'uv': 3.0},
#    {'time_epoch': 1700236800,
#     'time': '2023-11-17 16:00',
#     'temp_c': 7.4,
#     'temp_f': 45.4,
#     'is_day': 1,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 3.1,
#     'wind_kph': 5.0,
#     'wind_degree': 297,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1022.0,
#     'pressure_in': 30.19,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 83,
#     'cloud': 25,
#     'feelslike_c': 6.8,
#     'feelslike_f': 44.3,
#     'windchill_c': 6.8,
#     'windchill_f': 44.3,
#     'heatindex_c': 7.4,
#     'heatindex_f': 45.4,
#     'dewpoint_c': 4.8,
#     'dewpoint_f': 40.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.2,
#     'gust_kph': 8.3,
#     'uv': 3.0},
#    {'time_epoch': 1700240400,
#     'time': '2023-11-17 17:00',
#     'temp_c': 6.9,
#     'temp_f': 44.4,
#     'is_day': 0,
#     'condition': {'text': 'Clear',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 2.0,
#     'wind_kph': 3.2,
#     'wind_degree': 285,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 85,
#     'cloud': 10,
#     'feelslike_c': 7.0,
#     'feelslike_f': 44.5,
#     'windchill_c': 7.0,
#     'windchill_f': 44.5,
#     'heatindex_c': 6.9,
#     'heatindex_f': 44.4,
#     'dewpoint_c': 4.6,
#     'dewpoint_f': 40.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.5,
#     'gust_kph': 5.6,
#     'uv': 1.0},
#    {'time_epoch': 1700244000,
#     'time': '2023-11-17 18:00',
#     'temp_c': 6.8,
#     'temp_f': 44.2,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 3.1,
#     'wind_kph': 5.0,
#     'wind_degree': 232,
#     'wind_dir': 'SW',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.2,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 86,
#     'cloud': 26,
#     'feelslike_c': 6.1,
#     'feelslike_f': 43.0,
#     'windchill_c': 6.1,
#     'windchill_f': 43.0,
#     'heatindex_c': 6.8,
#     'heatindex_f': 44.2,
#     'dewpoint_c': 4.6,
#     'dewpoint_f': 40.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.3,
#     'gust_kph': 8.6,
#     'uv': 1.0},
#    {'time_epoch': 1700247600,
#     'time': '2023-11-17 19:00',
#     'temp_c': 6.4,
#     'temp_f': 43.5,
#     'is_day': 0,
#     'condition': {'text': 'Clear',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 2.7,
#     'wind_kph': 4.3,
#     'wind_degree': 220,
#     'wind_dir': 'SW',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.21,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 87,
#     'cloud': 15,
#     'feelslike_c': 5.9,
#     'feelslike_f': 42.6,
#     'windchill_c': 5.9,
#     'windchill_f': 42.6,
#     'heatindex_c': 6.4,
#     'heatindex_f': 43.4,
#     'dewpoint_c': 4.4,
#     'dewpoint_f': 40.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.7,
#     'gust_kph': 7.6,
#     'uv': 1.0},
#    {'time_epoch': 1700251200,
#     'time': '2023-11-17 20:00',
#     'temp_c': 6.2,
#     'temp_f': 43.1,
#     'is_day': 0,
#     'condition': {'text': 'Cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#      'code': 1006},
#     'wind_mph': 2.5,
#     'wind_kph': 4.0,
#     'wind_degree': 206,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.22,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 88,
#     'cloud': 73,
#     'feelslike_c': 5.8,
#     'feelslike_f': 42.5,
#     'windchill_c': 5.8,
#     'windchill_f': 42.5,
#     'heatindex_c': 6.2,
#     'heatindex_f': 43.1,
#     'dewpoint_c': 4.3,
#     'dewpoint_f': 39.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.3,
#     'gust_kph': 7.0,
#     'uv': 1.0},
#    {'time_epoch': 1700254800,
#     'time': '2023-11-17 21:00',
#     'temp_c': 6.1,
#     'temp_f': 43.1,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 2.9,
#     'wind_kph': 4.7,
#     'wind_degree': 183,
#     'wind_dir': 'S',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.22,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 88,
#     'cloud': 58,
#     'feelslike_c': 5.5,
#     'feelslike_f': 41.9,
#     'windchill_c': 5.5,
#     'windchill_f': 41.9,
#     'heatindex_c': 6.1,
#     'heatindex_f': 43.1,
#     'dewpoint_c': 4.2,
#     'dewpoint_f': 39.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.1,
#     'gust_kph': 8.2,
#     'uv': 1.0},
#    {'time_epoch': 1700258400,
#     'time': '2023-11-17 22:00',
#     'temp_c': 6.3,
#     'temp_f': 43.4,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 2.9,
#     'wind_kph': 4.7,
#     'wind_degree': 174,
#     'wind_dir': 'S',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.22,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 86,
#     'cloud': 54,
#     'feelslike_c': 5.7,
#     'feelslike_f': 42.3,
#     'windchill_c': 5.7,
#     'windchill_f': 42.3,
#     'heatindex_c': 6.3,
#     'heatindex_f': 43.4,
#     'dewpoint_c': 4.2,
#     'dewpoint_f': 39.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.9,
#     'gust_kph': 7.8,
#     'uv': 1.0},
#    {'time_epoch': 1700262000,
#     'time': '2023-11-17 23:00',
#     'temp_c': 6.4,
#     'temp_f': 43.6,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 159,
#     'wind_dir': 'SSE',
#     'pressure_mb': 1023.0,
#     'pressure_in': 30.21,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'humidity': 85,
#     'cloud': 60,
#     'feelslike_c': 5.5,
#     'feelslike_f': 41.8,
#     'windchill_c': 5.5,
#     'windchill_f': 41.8,
#     'heatindex_c': 6.5,
#     'heatindex_f': 43.6,
#     'dewpoint_c': 4.2,
#     'dewpoint_f': 39.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.9,
#     'gust_kph': 9.5,
#     'uv': 1.0}]}]

# %%
data['forecast']['forecastday'][0]['date']
# Out:
# '2023-11-15'

# %%
print(f'The dates of the three forecast days are:')
for date in data['forecast']['forecastday']:
    print(date['date'])
# Out:
# The dates of the three forecast days are:
# 2023-11-15
# 2023-11-16
# 2023-11-17

# %% [markdown]
# ## Print the maximum temperature of each of the days.

# %%
data['forecast']['forecastday'][0]['day'].keys()
# Out:
# dict_keys(['maxtemp_c', 'maxtemp_f', 'mintemp_c', 'mintemp_f', 'avgtemp_c', 'avgtemp_f', 'maxwind_mph', 'maxwind_kph', 'totalprecip_mm', 'totalprecip_in', 'totalsnow_cm', 'avgvis_km', 'avgvis_miles', 'avghumidity', 'daily_will_it_rain', 'daily_chance_of_rain', 'daily_will_it_snow', 'daily_chance_of_snow', 'condition', 'uv'])

# %%
data['forecast']['forecastday'][0]['day']['maxtemp_c']
# Out:
# 10.8

# %%
for max in data['forecast']['forecastday']:
    print(f"The max temperature on {date['date']} is forecasted to be {max['day']['maxtemp_c']} degrees Celsius.")
# Out:
# The max temperature on 2023-11-17 is forecasted to be 10.8 degrees Celsius.
# The max temperature on 2023-11-17 is forecasted to be 11.4 degrees Celsius.
# The max temperature on 2023-11-17 is forecasted to be 8.5 degrees Celsius.

# %% [markdown]
# ## Print only the day with the highest maximum temperature.

# %%
max_temp = 0
for max in data['forecast']['forecastday']:
    if max['day']['maxtemp_c'] > max_temp:
        max_temp = max['day']['maxtemp_c']
        max_date = date['date']
print(f'Of the three days forecasted, the maximum temperature forecasted is {max_temp} degrees Celsius on {max_date}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[109], line 2
#       1 for max in data['forecast']['forecastday']:
# ----> 2     if max['day']['maxtemp_c'] > max_temp:
#       3         max_temp = max['day']['maxtemp_c']
#       4         max_date = date['date']
#
# NameError: name 'max_temp' is not defined
